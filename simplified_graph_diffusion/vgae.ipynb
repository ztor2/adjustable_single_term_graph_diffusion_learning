# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
from vgae.model import GCN_VAE
from vgae.optimizer import loss_function
from vgae.utils import *
import numpy as np
import pandas as pd
import scipy.sparse as sp
import torch
from torch import optim
import torch.nn.functional as F
from datetime import datetime, timedelta
import time
import json
from collections import OrderedDict
import warnings; warnings.filterwarnings('ignore')

# %%
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 1.10.0+cu111
# 11.1

# %% [markdown]
# ### Settings

# %%
model_name = 'vgae'
dataset = 'cora' # 'citeseer', 'cora', 'pubmed', 'arx'
task = 'link_prediction' # 'classification', 'link_prediction'
feature_use = True # option only for link prediction
feat_norm = False
n_iter = 10

# %%
hidden1 = 32
hidden2 = 16
lr = 0.01
dropout = 0.
epochs = 200
test_val_ratio = [0.1, 0.05] # len_test = len_total * test_ratio, len_val = len_total * val_ratio
n_diff_range = [1,2,3,4,5]
alpha_range = [0.1, 0.3, 0.5, 0.7, 0.9]

# %%
# n_diff = 5
# alpha = 0.5
# hparams = epochs, hidden1, hidden2, lr, dropout, test_val_ratio, n_diff, alpha

# %% [markdown]
# ### Import dataset

# %%
if task == 'link_prediction':
    adj, features = load_data(dataset, task, feat_norm)
elif task == 'classification':
    adj, features, labels = load_data(dataset, task, feat_norm)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### VGAE(iterative operation)

# %%
for n_diff in n_diff_range:
    for alpha in alpha_range:
        
        hparams = epochs, hidden1, hidden2, lr, dropout, test_val_ratio, n_diff, alpha
        
        results = vgae_iter(adj, features, hparams, feature_use=feature_use, n_iter=n_iter)
        
        date = (datetime.now() + timedelta(hours=9)).strftime("%Y-%m-%d %H:%M:%S")
        hparams_add = hparams[:-2] + (feat_norm,) + (feature_use,)
        if n_diff == 1 and alpha == 0.5:
            experiment_mode = 'normal mode(n_diff={}, alpha={})'.format(n_diff, alpha)
        else:
            experiment_mode = 'simplified diffusion mode(n_diff={}, alpha={})'.format(n_diff, alpha)

        log_dict= OrderedDict()
        log_dict['model'] = model_name
        log_dict['dataset'] = dataset
        log_dict['datetime'] = date
        log_dict['experiment mode'] =  experiment_mode
        log_dict['setting_order'] = ['epochs', 'hidden1', 'hidden2', 'lr', 'dropout', 'test_val_ratio', 'feat_norm', 'feat_use']
        log_dict['setting_value'] = hparams_add
        log_dict['iteration'] = n_iter
        log_dict['roc'] = results[0]
        log_dict['roc_mean'] = np.mean(results[0])
        log_dict['roc_std'] = np.std(results[0])
        log_dict['ap'] = results[1]
        log_dict['ap_mean'] = np.mean(results[1])
        log_dict['ap_std'] = np.std(results[1])
        log_dict['elapsed time(s)'] = np.round(results[2], 4)
        print(pd.DataFrame(log_dict.items(), columns=['key', 'value']))
 
        data = json.load(open('results_link_prediction.json'))
        data.append(log_dict)
        with open('results_link_prediction.json', 'w') as f:
            json.dump(data, f)
        print("Last data saved at: {}".format((datetime.now() + timedelta(hours=9)).strftime("%Y-%m-%d %H:%M:%S")))
        print("Total data num: {}".format(len(data)))
# Out:
# Dataset: cora
# Simdiff_params: n_diff =  1, alpha = 0.1
# Start time: 2021-12-23 17:04:03
# Experiment 1 - 1/200 val_roc: 0.6114 val_ap: 0.5965
# Experiment 1 - 51/200 val_roc: 0.8858 val_ap: 0.8782
# Experiment 1 - 101/200 val_roc: 0.8850 val_ap: 0.8760
# Experiment 1 - 151/200 val_roc: 0.8774 val_ap: 0.8730
# Experiment 1 result - ROC(AUC) score: 0.90014, AP score: 0.90978
# Experiment 2 - 1/200 val_roc: 0.5631 val_ap: 0.5574
# Experiment 2 - 51/200 val_roc: 0.8929 val_ap: 0.8956
# Experiment 2 - 101/200 val_roc: 0.9075 val_ap: 0.9139
# Experiment 2 - 151/200 val_roc: 0.9109 val_ap: 0.9174
# Experiment 2 result - ROC(AUC) score: 0.89999, AP score: 0.90334
# Experiment 3 - 1/200 val_roc: 0.6437 val_ap: 0.6308
# Experiment 3 - 51/200 val_roc: 0.8717 val_ap: 0.8696
# Experiment 3 - 101/200 val_roc: 0.8833 val_ap: 0.8842
# Experiment 3 - 151/200 val_roc: 0.8872 val_ap: 0.8882
# Experiment 3 result - ROC(AUC) score: 0.88098, AP score: 0.89241
# Experiment 4 - 1/200 val_roc: 0.5982 val_ap: 0.5704
# Experiment 4 - 51/200 val_roc: 0.8719 val_ap: 0.8762
# Experiment 4 - 101/200 val_roc: 0.8885 val_ap: 0.8958
# Experiment 4 - 151/200 val_roc: 0.8942 val_ap: 0.9044
# Experiment 4 result - ROC(AUC) score: 0.89207, AP score: 0.89382
# Experiment 5 - 1/200 val_roc: 0.6105 val_ap: 0.6091
# Experiment 5 - 51/200 val_roc: 0.8544 val_ap: 0.8590
# Experiment 5 - 101/200 val_roc: 0.8731 val_ap: 0.8778
# Experiment 5 - 151/200 val_roc: 0.8733 val_ap: 0.8765
# Experiment 5 result - ROC(AUC) score: 0.89774, AP score: 0.90799
# Experiment 6 - 1/200 val_roc: 0.5725 val_ap: 0.5540
# Experiment 6 - 51/200 val_roc: 0.8842 val_ap: 0.8809
# Experiment 6 - 101/200 val_roc: 0.8918 val_ap: 0.9017
# Experiment 6 - 151/200 val_roc: 0.8911 val_ap: 0.9071
# Experiment 6 result - ROC(AUC) score: 0.90399, AP score: 0.91591
# Experiment 7 - 1/200 val_roc: 0.5498 val_ap: 0.5666
# Experiment 7 - 51/200 val_roc: 0.8920 val_ap: 0.9010
# Experiment 7 - 101/200 val_roc: 0.8929 val_ap: 0.9064
# Experiment 7 - 151/200 val_roc: 0.8914 val_ap: 0.9067
# Experiment 7 result - ROC(AUC) score: 0.90337, AP score: 0.91124
# Experiment 8 - 1/200 val_roc: 0.6538 val_ap: 0.6472
# Experiment 8 - 51/200 val_roc: 0.8393 val_ap: 0.8354
# Experiment 8 - 101/200 val_roc: 0.8712 val_ap: 0.8647
# Experiment 8 - 151/200 val_roc: 0.8822 val_ap: 0.8889
# Experiment 8 result - ROC(AUC) score: 0.89868, AP score: 0.89848
# Experiment 9 - 1/200 val_roc: 0.5893 val_ap: 0.5875
# Experiment 9 - 51/200 val_roc: 0.8575 val_ap: 0.8589
# Experiment 9 - 101/200 val_roc: 0.8718 val_ap: 0.8729
# Experiment 9 - 151/200 val_roc: 0.8691 val_ap: 0.8709
# Experiment 9 result - ROC(AUC) score: 0.90404, AP score: 0.90842
# Experiment 10 - 1/200 val_roc: 0.6102 val_ap: 0.6006
# Experiment 10 - 51/200 val_roc: 0.8698 val_ap: 0.8773
# Experiment 10 - 101/200 val_roc: 0.8744 val_ap: 0.8802
# Experiment 10 - 151/200 val_roc: 0.8754 val_ap: 0.8817
# Experiment 10 result - ROC(AUC) score: 0.89313, AP score: 0.9038
# All experiments finished!
# Elapsed time: 103.02s
# End time: 2021-12-23 17:05:46
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:05:46
# 3   experiment mode      k-th order sampling mode(n_diff=1, alpha=0.1)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.9001364639630718, 0.8999852374076888, 0.880...
# 8          roc_mean                                           0.897414
# 9           roc_std                                         0.00674764
# 10               ap  [0.9097791315370275, 0.903340474197509, 0.8924...
# 11          ap_mean                                           0.904518
# 12           ap_std                                         0.00727589
# 13  elapsed time(s)                                            103.023
# Last data saved at: 2021-12-23 17:05:46
# Total data num: 76
# Dataset: cora
# Simdiff_params: n_diff =  1, alpha = 0.3
# Start time: 2021-12-23 17:05:46
# Experiment 1 - 1/200 val_roc: 0.6290 val_ap: 0.6188
# Experiment 1 - 51/200 val_roc: 0.9057 val_ap: 0.9111
# Experiment 1 - 101/200 val_roc: 0.9146 val_ap: 0.9190
# Experiment 1 - 151/200 val_roc: 0.9185 val_ap: 0.9245
# Experiment 1 result - ROC(AUC) score: 0.90159, AP score: 0.91769
# Experiment 2 - 1/200 val_roc: 0.6846 val_ap: 0.6826
# Experiment 2 - 51/200 val_roc: 0.8323 val_ap: 0.8488
# Experiment 2 - 101/200 val_roc: 0.8610 val_ap: 0.8800
# Experiment 2 - 151/200 val_roc: 0.8628 val_ap: 0.8781
# Experiment 2 result - ROC(AUC) score: 0.91111, AP score: 0.92261
# Experiment 3 - 1/200 val_roc: 0.6545 val_ap: 0.6696
# Experiment 3 - 51/200 val_roc: 0.8635 val_ap: 0.8720
# Experiment 3 - 101/200 val_roc: 0.8861 val_ap: 0.8960
# Experiment 3 - 151/200 val_roc: 0.8907 val_ap: 0.9014
# Experiment 3 result - ROC(AUC) score: 0.90595, AP score: 0.91205
# Experiment 4 - 1/200 val_roc: 0.6355 val_ap: 0.6599
# Experiment 4 - 51/200 val_roc: 0.9080 val_ap: 0.9084
# Experiment 4 - 101/200 val_roc: 0.9169 val_ap: 0.9236
# Experiment 4 - 151/200 val_roc: 0.9176 val_ap: 0.9253
# Experiment 4 result - ROC(AUC) score: 0.90394, AP score: 0.92017
# Experiment 5 - 1/200 val_roc: 0.6451 val_ap: 0.6490
# Experiment 5 - 51/200 val_roc: 0.8577 val_ap: 0.8548
# Experiment 5 - 101/200 val_roc: 0.8901 val_ap: 0.8958
# Experiment 5 - 151/200 val_roc: 0.9048 val_ap: 0.9115
# Experiment 5 result - ROC(AUC) score: 0.91205, AP score: 0.91706
# Experiment 6 - 1/200 val_roc: 0.6276 val_ap: 0.6382
# Experiment 6 - 51/200 val_roc: 0.8915 val_ap: 0.9058
# Experiment 6 - 101/200 val_roc: 0.8960 val_ap: 0.9162
# Experiment 6 - 151/200 val_roc: 0.8936 val_ap: 0.9170
# Experiment 6 result - ROC(AUC) score: 0.88509, AP score: 0.90358
# Experiment 7 - 1/200 val_roc: 0.6332 val_ap: 0.6432
# Experiment 7 - 51/200 val_roc: 0.8871 val_ap: 0.8953
# Experiment 7 - 101/200 val_roc: 0.9112 val_ap: 0.9214
# Experiment 7 - 151/200 val_roc: 0.9156 val_ap: 0.9257
# Experiment 7 result - ROC(AUC) score: 0.88639, AP score: 0.89314
# Experiment 8 - 1/200 val_roc: 0.6189 val_ap: 0.6209
# Experiment 8 - 51/200 val_roc: 0.8602 val_ap: 0.8762
# Experiment 8 - 101/200 val_roc: 0.8719 val_ap: 0.8868
# Experiment 8 - 151/200 val_roc: 0.8762 val_ap: 0.8949
# Experiment 8 result - ROC(AUC) score: 0.90074, AP score: 0.91408
# Experiment 9 - 1/200 val_roc: 0.7028 val_ap: 0.6793
# Experiment 9 - 51/200 val_roc: 0.9044 val_ap: 0.9156
# Experiment 9 - 101/200 val_roc: 0.9151 val_ap: 0.9244
# Experiment 9 - 151/200 val_roc: 0.9147 val_ap: 0.9250
# Experiment 9 result - ROC(AUC) score: 0.90221, AP score: 0.9064
# Experiment 10 - 1/200 val_roc: 0.6437 val_ap: 0.6581
# Experiment 10 - 51/200 val_roc: 0.8761 val_ap: 0.8877
# Experiment 10 - 101/200 val_roc: 0.9065 val_ap: 0.9242
# Experiment 10 - 151/200 val_roc: 0.8981 val_ap: 0.9180
# Experiment 10 result - ROC(AUC) score: 0.9031, AP score: 0.90863
# All experiments finished!
# Elapsed time: 103.44s
# End time: 2021-12-23 17:07:29
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:07:29
# 3   experiment mode      k-th order sampling mode(n_diff=1, alpha=0.3)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.9015875187682957, 0.9111075904928907, 0.905...
# 8          roc_mean                                           0.901216
# 9           roc_std                                         0.00854277
# 10               ap  [0.9176936197377864, 0.9226089138151072, 0.912...
# 11          ap_mean                                           0.911542
# 12           ap_std                                         0.00841949
# 13  elapsed time(s)                                            103.444
# Last data saved at: 2021-12-23 17:07:29
# Total data num: 77
# Dataset: cora
# Simdiff_params: n_diff =  1, alpha = 0.5
# Start time: 2021-12-23 17:07:29
# Experiment 1 - 1/200 val_roc: 0.6406 val_ap: 0.6505
# Experiment 1 - 51/200 val_roc: 0.8639 val_ap: 0.8679
# Experiment 1 - 101/200 val_roc: 0.8952 val_ap: 0.8967
# Experiment 1 - 151/200 val_roc: 0.8933 val_ap: 0.8935
# Experiment 1 result - ROC(AUC) score: 0.9085, AP score: 0.91654
# Experiment 2 - 1/200 val_roc: 0.6693 val_ap: 0.6846
# Experiment 2 - 51/200 val_roc: 0.8450 val_ap: 0.8740
# Experiment 2 - 101/200 val_roc: 0.8707 val_ap: 0.8891
# Experiment 2 - 151/200 val_roc: 0.8801 val_ap: 0.8986
# Experiment 2 result - ROC(AUC) score: 0.90108, AP score: 0.91262
# Experiment 3 - 1/200 val_roc: 0.7064 val_ap: 0.7247
# Experiment 3 - 51/200 val_roc: 0.8611 val_ap: 0.8750
# Experiment 3 - 101/200 val_roc: 0.8807 val_ap: 0.8987
# Experiment 3 - 151/200 val_roc: 0.8877 val_ap: 0.8970
# Experiment 3 result - ROC(AUC) score: 0.896, AP score: 0.90806
# Experiment 4 - 1/200 val_roc: 0.6665 val_ap: 0.7018
# Experiment 4 - 51/200 val_roc: 0.9024 val_ap: 0.9167
# Experiment 4 - 101/200 val_roc: 0.9204 val_ap: 0.9350
# Experiment 4 - 151/200 val_roc: 0.9202 val_ap: 0.9314
# Experiment 4 result - ROC(AUC) score: 0.90729, AP score: 0.90992
# Experiment 5 - 1/200 val_roc: 0.7086 val_ap: 0.7357
# Experiment 5 - 51/200 val_roc: 0.8824 val_ap: 0.8882
# Experiment 5 - 101/200 val_roc: 0.8867 val_ap: 0.8997
# Experiment 5 - 151/200 val_roc: 0.8846 val_ap: 0.9008
# Experiment 5 result - ROC(AUC) score: 0.89782, AP score: 0.91514
# Experiment 6 - 1/200 val_roc: 0.6571 val_ap: 0.6738
# Experiment 6 - 51/200 val_roc: 0.8595 val_ap: 0.8758
# Experiment 6 - 101/200 val_roc: 0.8818 val_ap: 0.8970
# Experiment 6 - 151/200 val_roc: 0.8805 val_ap: 0.8958
# Experiment 6 result - ROC(AUC) score: 0.88756, AP score: 0.90311
# Experiment 7 - 1/200 val_roc: 0.6969 val_ap: 0.7131
# Experiment 7 - 51/200 val_roc: 0.9012 val_ap: 0.9109
# Experiment 7 - 101/200 val_roc: 0.9149 val_ap: 0.9264
# Experiment 7 - 151/200 val_roc: 0.9130 val_ap: 0.9229
# Experiment 7 result - ROC(AUC) score: 0.91719, AP score: 0.92587
# Experiment 8 - 1/200 val_roc: 0.6708 val_ap: 0.6618
# Experiment 8 - 51/200 val_roc: 0.8752 val_ap: 0.8682
# Experiment 8 - 101/200 val_roc: 0.8845 val_ap: 0.8869
# Experiment 8 - 151/200 val_roc: 0.8890 val_ap: 0.9023
# Experiment 8 result - ROC(AUC) score: 0.90821, AP score: 0.92274
# Experiment 9 - 1/200 val_roc: 0.6584 val_ap: 0.6423
# Experiment 9 - 51/200 val_roc: 0.8897 val_ap: 0.8956
# Experiment 9 - 101/200 val_roc: 0.9110 val_ap: 0.9169
# Experiment 9 - 151/200 val_roc: 0.9125 val_ap: 0.9197
# Experiment 9 result - ROC(AUC) score: 0.90899, AP score: 0.92081
# Experiment 10 - 1/200 val_roc: 0.6644 val_ap: 0.6595
# Experiment 10 - 51/200 val_roc: 0.8640 val_ap: 0.8666
# Experiment 10 - 101/200 val_roc: 0.8857 val_ap: 0.8948
# Experiment 10 - 151/200 val_roc: 0.8962 val_ap: 0.9051
# Experiment 10 result - ROC(AUC) score: 0.91039, AP score: 0.91096
# All experiments finished!
# Elapsed time: 102.17s
# End time: 2021-12-23 17:09:11
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:09:11
# 3   experiment mode      k-th order sampling mode(n_diff=1, alpha=0.5)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.908500732728667, 0.901083430250352, 0.89599...
# 8          roc_mean                                           0.904302
# 9           roc_std                                         0.00817589
# 10               ap  [0.9165395541892812, 0.9126248146658789, 0.908...
# 11          ap_mean                                           0.914576
# 12           ap_std                                         0.00670637
# 13  elapsed time(s)                                            102.172
# Last data saved at: 2021-12-23 17:09:11
# Total data num: 78
# Dataset: cora
# Simdiff_params: n_diff =  1, alpha = 0.7
# Start time: 2021-12-23 17:09:11
# Experiment 1 - 1/200 val_roc: 0.6949 val_ap: 0.6948
# Experiment 1 - 51/200 val_roc: 0.8902 val_ap: 0.9007
# Experiment 1 - 101/200 val_roc: 0.8931 val_ap: 0.9080
# Experiment 1 - 151/200 val_roc: 0.8912 val_ap: 0.9110
# Experiment 1 result - ROC(AUC) score: 0.89959, AP score: 0.91325
# Experiment 2 - 1/200 val_roc: 0.6976 val_ap: 0.7217
# Experiment 2 - 51/200 val_roc: 0.8802 val_ap: 0.8839
# Experiment 2 - 101/200 val_roc: 0.8946 val_ap: 0.9009
# Experiment 2 - 151/200 val_roc: 0.8958 val_ap: 0.9041
# Experiment 2 result - ROC(AUC) score: 0.89728, AP score: 0.90357
# Experiment 3 - 1/200 val_roc: 0.6605 val_ap: 0.6753
# Experiment 3 - 51/200 val_roc: 0.8641 val_ap: 0.8728
# Experiment 3 - 101/200 val_roc: 0.8809 val_ap: 0.8933
# Experiment 3 - 151/200 val_roc: 0.8890 val_ap: 0.9037
# Experiment 3 result - ROC(AUC) score: 0.90459, AP score: 0.91457
# Experiment 4 - 1/200 val_roc: 0.6646 val_ap: 0.6955
# Experiment 4 - 51/200 val_roc: 0.8011 val_ap: 0.7894
# Experiment 4 - 101/200 val_roc: 0.8356 val_ap: 0.8137
# Experiment 4 - 151/200 val_roc: 0.8396 val_ap: 0.8186
# Experiment 4 result - ROC(AUC) score: 0.83626, AP score: 0.83694
# Experiment 5 - 1/200 val_roc: 0.6984 val_ap: 0.7290
# Experiment 5 - 51/200 val_roc: 0.8744 val_ap: 0.8807
# Experiment 5 - 101/200 val_roc: 0.9021 val_ap: 0.9045
# Experiment 5 - 151/200 val_roc: 0.9066 val_ap: 0.9137
# Experiment 5 result - ROC(AUC) score: 0.89773, AP score: 0.90535
# Experiment 6 - 1/200 val_roc: 0.6780 val_ap: 0.6960
# Experiment 6 - 51/200 val_roc: 0.8951 val_ap: 0.8951
# Experiment 6 - 101/200 val_roc: 0.9084 val_ap: 0.9129
# Experiment 6 - 151/200 val_roc: 0.9181 val_ap: 0.9218
# Experiment 6 result - ROC(AUC) score: 0.90638, AP score: 0.91388
# Experiment 7 - 1/200 val_roc: 0.6844 val_ap: 0.6974
# Experiment 7 - 51/200 val_roc: 0.8794 val_ap: 0.8753
# Experiment 7 - 101/200 val_roc: 0.8858 val_ap: 0.8921
# Experiment 7 - 151/200 val_roc: 0.8876 val_ap: 0.8996
# Experiment 7 result - ROC(AUC) score: 0.88986, AP score: 0.90315
# Experiment 8 - 1/200 val_roc: 0.6237 val_ap: 0.6419
# Experiment 8 - 51/200 val_roc: 0.8679 val_ap: 0.8714
# Experiment 8 - 101/200 val_roc: 0.8821 val_ap: 0.8895
# Experiment 8 - 151/200 val_roc: 0.8885 val_ap: 0.8977
# Experiment 8 result - ROC(AUC) score: 0.90754, AP score: 0.91557
# Experiment 9 - 1/200 val_roc: 0.7131 val_ap: 0.7351
# Experiment 9 - 51/200 val_roc: 0.8765 val_ap: 0.8786
# Experiment 9 - 101/200 val_roc: 0.9036 val_ap: 0.9075
# Experiment 9 - 151/200 val_roc: 0.8949 val_ap: 0.8937
# Experiment 9 result - ROC(AUC) score: 0.90468, AP score: 0.91679
# Experiment 10 - 1/200 val_roc: 0.7069 val_ap: 0.7253
# Experiment 10 - 51/200 val_roc: 0.9143 val_ap: 0.9163
# Experiment 10 - 101/200 val_roc: 0.9278 val_ap: 0.9322
# Experiment 10 - 151/200 val_roc: 0.9278 val_ap: 0.9353
# Experiment 10 result - ROC(AUC) score: 0.90252, AP score: 0.92023
# All experiments finished!
# Elapsed time: 101.75s
# End time: 2021-12-23 17:10:53
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:10:53
# 3   experiment mode      k-th order sampling mode(n_diff=1, alpha=0.7)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.8995855672256047, 0.8972847632044186, 0.904...
# 8          roc_mean                                           0.894644
# 9           roc_std                                          0.0200951
# 10               ap  [0.9132489130849102, 0.9035671442304696, 0.914...
# 11          ap_mean                                            0.90433
# 12           ap_std                                          0.0231383
# 13  elapsed time(s)                                             101.75
# Last data saved at: 2021-12-23 17:10:53
# Total data num: 79
# Dataset: cora
# Simdiff_params: n_diff =  1, alpha = 0.9
# Start time: 2021-12-23 17:10:53
# Experiment 1 - 1/200 val_roc: 0.6867 val_ap: 0.7030
# Experiment 1 - 51/200 val_roc: 0.8475 val_ap: 0.8493
# Experiment 1 - 101/200 val_roc: 0.8684 val_ap: 0.8876
# Experiment 1 - 151/200 val_roc: 0.8869 val_ap: 0.9056
# Experiment 1 result - ROC(AUC) score: 0.90067, AP score: 0.91267
# Experiment 2 - 1/200 val_roc: 0.6932 val_ap: 0.6925
# Experiment 2 - 51/200 val_roc: 0.8725 val_ap: 0.8760
# Experiment 2 - 101/200 val_roc: 0.8715 val_ap: 0.8859
# Experiment 2 - 151/200 val_roc: 0.8754 val_ap: 0.8842
# Experiment 2 result - ROC(AUC) score: 0.90431, AP score: 0.91616
# Experiment 3 - 1/200 val_roc: 0.7265 val_ap: 0.7380
# Experiment 3 - 51/200 val_roc: 0.8217 val_ap: 0.8313
# Experiment 3 - 101/200 val_roc: 0.8498 val_ap: 0.8587
# Experiment 3 - 151/200 val_roc: 0.8570 val_ap: 0.8694
# Experiment 3 result - ROC(AUC) score: 0.88738, AP score: 0.89288
# Experiment 4 - 1/200 val_roc: 0.6788 val_ap: 0.6985
# Experiment 4 - 51/200 val_roc: 0.8588 val_ap: 0.8711
# Experiment 4 - 101/200 val_roc: 0.8704 val_ap: 0.8862
# Experiment 4 - 151/200 val_roc: 0.8681 val_ap: 0.8899
# Experiment 4 result - ROC(AUC) score: 0.89614, AP score: 0.89099
# Experiment 5 - 1/200 val_roc: 0.7211 val_ap: 0.7314
# Experiment 5 - 51/200 val_roc: 0.8546 val_ap: 0.8515
# Experiment 5 - 101/200 val_roc: 0.8757 val_ap: 0.8783
# Experiment 5 - 151/200 val_roc: 0.8809 val_ap: 0.8836
# Experiment 5 result - ROC(AUC) score: 0.91093, AP score: 0.91698
# Experiment 6 - 1/200 val_roc: 0.6703 val_ap: 0.6914
# Experiment 6 - 51/200 val_roc: 0.8887 val_ap: 0.8972
# Experiment 6 - 101/200 val_roc: 0.9032 val_ap: 0.9095
# Experiment 6 - 151/200 val_roc: 0.9088 val_ap: 0.9155
# Experiment 6 result - ROC(AUC) score: 0.90388, AP score: 0.89903
# Experiment 7 - 1/200 val_roc: 0.6803 val_ap: 0.6650
# Experiment 7 - 51/200 val_roc: 0.8328 val_ap: 0.8284
# Experiment 7 - 101/200 val_roc: 0.8715 val_ap: 0.8583
# Experiment 7 - 151/200 val_roc: 0.8819 val_ap: 0.8639
# Experiment 7 result - ROC(AUC) score: 0.88296, AP score: 0.89258
# Experiment 8 - 1/200 val_roc: 0.7639 val_ap: 0.7586
# Experiment 8 - 51/200 val_roc: 0.9159 val_ap: 0.9135
# Experiment 8 - 101/200 val_roc: 0.9177 val_ap: 0.9178
# Experiment 8 - 151/200 val_roc: 0.9183 val_ap: 0.9261
# Experiment 8 result - ROC(AUC) score: 0.90941, AP score: 0.91734
# Experiment 9 - 1/200 val_roc: 0.6968 val_ap: 0.7181
# Experiment 9 - 51/200 val_roc: 0.9001 val_ap: 0.9063
# Experiment 9 - 101/200 val_roc: 0.9219 val_ap: 0.9272
# Experiment 9 - 151/200 val_roc: 0.9287 val_ap: 0.9317
# Experiment 9 result - ROC(AUC) score: 0.90152, AP score: 0.90491
# Experiment 10 - 1/200 val_roc: 0.6441 val_ap: 0.6445
# Experiment 10 - 51/200 val_roc: 0.8773 val_ap: 0.8864
# Experiment 10 - 101/200 val_roc: 0.8879 val_ap: 0.8979
# Experiment 10 - 151/200 val_roc: 0.8894 val_ap: 0.8985
# Experiment 10 result - ROC(AUC) score: 0.88019, AP score: 0.9001
# All experiments finished!
# Elapsed time: 102.05s
# End time: 2021-12-23 17:12:35
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:12:35
# 3   experiment mode      k-th order sampling mode(n_diff=1, alpha=0.9)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.9006693575391839, 0.904305996132921, 0.8873...
# 8          roc_mean                                           0.897737
# 9           roc_std                                          0.0102495
# 10               ap  [0.912668720640254, 0.9161635050352253, 0.8928...
# 11          ap_mean                                           0.904363
# 12           ap_std                                          0.0101612
# 13  elapsed time(s)                                            102.053
# Last data saved at: 2021-12-23 17:12:35
# Total data num: 80
# Dataset: cora
# Simdiff_params: n_diff =  2, alpha = 0.1
# Start time: 2021-12-23 17:12:35
# Experiment 1 - 1/200 val_roc: 0.6465 val_ap: 0.6355
# Experiment 1 - 51/200 val_roc: 0.7574 val_ap: 0.7651
# Experiment 1 - 101/200 val_roc: 0.8070 val_ap: 0.8093
# Experiment 1 - 151/200 val_roc: 0.8224 val_ap: 0.8256
# Experiment 1 result - ROC(AUC) score: 0.84695, AP score: 0.84337
# Experiment 2 - 1/200 val_roc: 0.6207 val_ap: 0.6024
# Experiment 2 - 51/200 val_roc: 0.7650 val_ap: 0.7647
# Experiment 2 - 101/200 val_roc: 0.8081 val_ap: 0.7957
# Experiment 2 - 151/200 val_roc: 0.8176 val_ap: 0.8087
# Experiment 2 result - ROC(AUC) score: 0.86221, AP score: 0.86484
# Experiment 3 - 1/200 val_roc: 0.6294 val_ap: 0.6323
# Experiment 3 - 51/200 val_roc: 0.7222 val_ap: 0.7042
# Experiment 3 - 101/200 val_roc: 0.7957 val_ap: 0.7955
# Experiment 3 - 151/200 val_roc: 0.8163 val_ap: 0.8159
# Experiment 3 result - ROC(AUC) score: 0.8335, AP score: 0.82846
# Experiment 4 - 1/200 val_roc: 0.6472 val_ap: 0.6508
# Experiment 4 - 51/200 val_roc: 0.8150 val_ap: 0.7971
# Experiment 4 - 101/200 val_roc: 0.8656 val_ap: 0.8554
# Experiment 4 - 151/200 val_roc: 0.8811 val_ap: 0.8752
# Experiment 4 result - ROC(AUC) score: 0.85024, AP score: 0.86151
# Experiment 5 - 1/200 val_roc: 0.6285 val_ap: 0.6052
# Experiment 5 - 51/200 val_roc: 0.7389 val_ap: 0.7398
# Experiment 5 - 101/200 val_roc: 0.7920 val_ap: 0.7817
# Experiment 5 - 151/200 val_roc: 0.8056 val_ap: 0.8038
# Experiment 5 result - ROC(AUC) score: 0.84505, AP score: 0.83949
# Experiment 6 - 1/200 val_roc: 0.6317 val_ap: 0.6111
# Experiment 6 - 51/200 val_roc: 0.6758 val_ap: 0.6650
# Experiment 6 - 101/200 val_roc: 0.7200 val_ap: 0.7247
# Experiment 6 - 151/200 val_roc: 0.7636 val_ap: 0.7651
# Experiment 6 result - ROC(AUC) score: 0.75144, AP score: 0.75716
# Experiment 7 - 1/200 val_roc: 0.6225 val_ap: 0.6113
# Experiment 7 - 51/200 val_roc: 0.7737 val_ap: 0.7572
# Experiment 7 - 101/200 val_roc: 0.8396 val_ap: 0.8307
# Experiment 7 - 151/200 val_roc: 0.8529 val_ap: 0.8492
# Experiment 7 result - ROC(AUC) score: 0.8634, AP score: 0.8597
# Experiment 8 - 1/200 val_roc: 0.6346 val_ap: 0.6426
# Experiment 8 - 51/200 val_roc: 0.7713 val_ap: 0.7608
# Experiment 8 - 101/200 val_roc: 0.8254 val_ap: 0.8265
# Experiment 8 - 151/200 val_roc: 0.8282 val_ap: 0.8033
# Experiment 8 result - ROC(AUC) score: 0.84564, AP score: 0.84854
# Experiment 9 - 1/200 val_roc: 0.5975 val_ap: 0.5902
# Experiment 9 - 51/200 val_roc: 0.6800 val_ap: 0.6825
# Experiment 9 - 101/200 val_roc: 0.8073 val_ap: 0.8153
# Experiment 9 - 151/200 val_roc: 0.8406 val_ap: 0.8459
# Experiment 9 result - ROC(AUC) score: 0.81435, AP score: 0.81775
# Experiment 10 - 1/200 val_roc: 0.6143 val_ap: 0.6150
# Experiment 10 - 51/200 val_roc: 0.7503 val_ap: 0.7520
# Experiment 10 - 101/200 val_roc: 0.7931 val_ap: 0.7963
# Experiment 10 - 151/200 val_roc: 0.8175 val_ap: 0.8200
# Experiment 10 result - ROC(AUC) score: 0.79252, AP score: 0.78857
# All experiments finished!
# Elapsed time: 105.71s
# End time: 2021-12-23 17:14:21
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:14:21
# 3   experiment mode      k-th order sampling mode(n_diff=2, alpha=0.1)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.846951524687735, 0.8622074036200756, 0.8335...
# 8          roc_mean                                            0.83053
# 9           roc_std                                          0.0333941
# 10               ap  [0.8433699455098432, 0.8648372245497935, 0.828...
# 11          ap_mean                                           0.830938
# 12           ap_std                                           0.032964
# 13  elapsed time(s)                                            105.706
# Last data saved at: 2021-12-23 17:14:21
# Total data num: 81
# Dataset: cora
# Simdiff_params: n_diff =  2, alpha = 0.3
# Start time: 2021-12-23 17:14:21
# Experiment 1 - 1/200 val_roc: 0.6541 val_ap: 0.6834
# Experiment 1 - 51/200 val_roc: 0.7882 val_ap: 0.7896
# Experiment 1 - 101/200 val_roc: 0.8431 val_ap: 0.8434
# Experiment 1 - 151/200 val_roc: 0.8615 val_ap: 0.8676
# Experiment 1 result - ROC(AUC) score: 0.83961, AP score: 0.84065
# Experiment 2 - 1/200 val_roc: 0.6983 val_ap: 0.7183
# Experiment 2 - 51/200 val_roc: 0.6591 val_ap: 0.6945
# Experiment 2 - 101/200 val_roc: 0.7480 val_ap: 0.7368
# Experiment 2 - 151/200 val_roc: 0.7737 val_ap: 0.7698
# Experiment 2 result - ROC(AUC) score: 0.75502, AP score: 0.75341
# Experiment 3 - 1/200 val_roc: 0.6544 val_ap: 0.6579
# Experiment 3 - 51/200 val_roc: 0.6749 val_ap: 0.6716
# Experiment 3 - 101/200 val_roc: 0.7599 val_ap: 0.7448
# Experiment 3 - 151/200 val_roc: 0.8049 val_ap: 0.7980
# Experiment 3 result - ROC(AUC) score: 0.83928, AP score: 0.84533
# Experiment 4 - 1/200 val_roc: 0.7072 val_ap: 0.7110
# Experiment 4 - 51/200 val_roc: 0.7753 val_ap: 0.7810
# Experiment 4 - 101/200 val_roc: 0.7764 val_ap: 0.7735
# Experiment 4 - 151/200 val_roc: 0.8018 val_ap: 0.8021
# Experiment 4 result - ROC(AUC) score: 0.8235, AP score: 0.82328
# Experiment 5 - 1/200 val_roc: 0.6633 val_ap: 0.6672
# Experiment 5 - 51/200 val_roc: 0.7721 val_ap: 0.7589
# Experiment 5 - 101/200 val_roc: 0.8326 val_ap: 0.8276
# Experiment 5 - 151/200 val_roc: 0.8438 val_ap: 0.8366
# Experiment 5 result - ROC(AUC) score: 0.86571, AP score: 0.87809
# Experiment 6 - 1/200 val_roc: 0.6683 val_ap: 0.6702
# Experiment 6 - 51/200 val_roc: 0.7381 val_ap: 0.7342
# Experiment 6 - 101/200 val_roc: 0.8099 val_ap: 0.8063
# Experiment 6 - 151/200 val_roc: 0.8402 val_ap: 0.8402
# Experiment 6 result - ROC(AUC) score: 0.86901, AP score: 0.8737
# Experiment 7 - 1/200 val_roc: 0.6829 val_ap: 0.6700
# Experiment 7 - 51/200 val_roc: 0.7597 val_ap: 0.7781
# Experiment 7 - 101/200 val_roc: 0.8299 val_ap: 0.8419
# Experiment 7 - 151/200 val_roc: 0.8565 val_ap: 0.8679
# Experiment 7 result - ROC(AUC) score: 0.84223, AP score: 0.85449
# Experiment 8 - 1/200 val_roc: 0.7358 val_ap: 0.7412
# Experiment 8 - 51/200 val_roc: 0.7686 val_ap: 0.7772
# Experiment 8 - 101/200 val_roc: 0.8210 val_ap: 0.8362
# Experiment 8 - 151/200 val_roc: 0.8458 val_ap: 0.8563
# Experiment 8 result - ROC(AUC) score: 0.84353, AP score: 0.84708
# Experiment 9 - 1/200 val_roc: 0.6377 val_ap: 0.6542
# Experiment 9 - 51/200 val_roc: 0.8162 val_ap: 0.8267
# Experiment 9 - 101/200 val_roc: 0.8371 val_ap: 0.8535
# Experiment 9 - 151/200 val_roc: 0.8445 val_ap: 0.8650
# Experiment 9 result - ROC(AUC) score: 0.86298, AP score: 0.86441
# Experiment 10 - 1/200 val_roc: 0.6708 val_ap: 0.6577
# Experiment 10 - 51/200 val_roc: 0.7818 val_ap: 0.8042
# Experiment 10 - 101/200 val_roc: 0.8270 val_ap: 0.8425
# Experiment 10 - 151/200 val_roc: 0.8428 val_ap: 0.8607
# Experiment 10 result - ROC(AUC) score: 0.85925, AP score: 0.86655
# All experiments finished!
# Elapsed time: 102.90s
# End time: 2021-12-23 17:16:04
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:16:04
# 3   experiment mode      k-th order sampling mode(n_diff=2, alpha=0.3)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.8396098354871115, 0.7550165809116081, 0.839...
# 8          roc_mean                                           0.840012
# 9           roc_std                                          0.0314858
# 10               ap  [0.8406502760220277, 0.75341004692387, 0.84532...
# 11          ap_mean                                           0.844699
# 12           ap_std                                          0.0342533
# 13  elapsed time(s)                                              102.9
# Last data saved at: 2021-12-23 17:16:04
# Total data num: 82
# Dataset: cora
# Simdiff_params: n_diff =  2, alpha = 0.5
# Start time: 2021-12-23 17:16:04
# Experiment 1 - 1/200 val_roc: 0.6699 val_ap: 0.6694
# Experiment 1 - 51/200 val_roc: 0.8448 val_ap: 0.8513
# Experiment 1 - 101/200 val_roc: 0.8611 val_ap: 0.8595
# Experiment 1 - 151/200 val_roc: 0.8677 val_ap: 0.8680
# Experiment 1 result - ROC(AUC) score: 0.88315, AP score: 0.89709
# Experiment 2 - 1/200 val_roc: 0.6834 val_ap: 0.6982
# Experiment 2 - 51/200 val_roc: 0.8497 val_ap: 0.8590
# Experiment 2 - 101/200 val_roc: 0.8701 val_ap: 0.8909
# Experiment 2 - 151/200 val_roc: 0.8771 val_ap: 0.9000
# Experiment 2 result - ROC(AUC) score: 0.89268, AP score: 0.90358
# Experiment 3 - 1/200 val_roc: 0.6752 val_ap: 0.7020
# Experiment 3 - 51/200 val_roc: 0.8178 val_ap: 0.8368
# Experiment 3 - 101/200 val_roc: 0.8663 val_ap: 0.8736
# Experiment 3 - 151/200 val_roc: 0.8784 val_ap: 0.8843
# Experiment 3 result - ROC(AUC) score: 0.86944, AP score: 0.89188
# Experiment 4 - 1/200 val_roc: 0.6803 val_ap: 0.6875
# Experiment 4 - 51/200 val_roc: 0.8509 val_ap: 0.8668
# Experiment 4 - 101/200 val_roc: 0.8784 val_ap: 0.8863
# Experiment 4 - 151/200 val_roc: 0.8899 val_ap: 0.8992
# Experiment 4 result - ROC(AUC) score: 0.90715, AP score: 0.91752
# Experiment 5 - 1/200 val_roc: 0.7344 val_ap: 0.7258
# Experiment 5 - 51/200 val_roc: 0.8464 val_ap: 0.8596
# Experiment 5 - 101/200 val_roc: 0.8681 val_ap: 0.8803
# Experiment 5 - 151/200 val_roc: 0.8705 val_ap: 0.8906
# Experiment 5 result - ROC(AUC) score: 0.87273, AP score: 0.87165
# Experiment 6 - 1/200 val_roc: 0.6833 val_ap: 0.6919
# Experiment 6 - 51/200 val_roc: 0.7984 val_ap: 0.8096
# Experiment 6 - 101/200 val_roc: 0.8423 val_ap: 0.8580
# Experiment 6 - 151/200 val_roc: 0.8556 val_ap: 0.8543
# Experiment 6 result - ROC(AUC) score: 0.87733, AP score: 0.88325
# Experiment 7 - 1/200 val_roc: 0.7199 val_ap: 0.7386
# Experiment 7 - 51/200 val_roc: 0.7902 val_ap: 0.8011
# Experiment 7 - 101/200 val_roc: 0.8705 val_ap: 0.8741
# Experiment 7 - 151/200 val_roc: 0.8883 val_ap: 0.8920
# Experiment 7 result - ROC(AUC) score: 0.87559, AP score: 0.88037
# Experiment 8 - 1/200 val_roc: 0.6940 val_ap: 0.7138
# Experiment 8 - 51/200 val_roc: 0.7540 val_ap: 0.7590
# Experiment 8 - 101/200 val_roc: 0.8014 val_ap: 0.7881
# Experiment 8 - 151/200 val_roc: 0.8122 val_ap: 0.8048
# Experiment 8 result - ROC(AUC) score: 0.83971, AP score: 0.83717
# Experiment 9 - 1/200 val_roc: 0.6697 val_ap: 0.6849
# Experiment 9 - 51/200 val_roc: 0.7667 val_ap: 0.7780
# Experiment 9 - 101/200 val_roc: 0.8090 val_ap: 0.8234
# Experiment 9 - 151/200 val_roc: 0.8286 val_ap: 0.8465
# Experiment 9 result - ROC(AUC) score: 0.8504, AP score: 0.84022
# Experiment 10 - 1/200 val_roc: 0.6846 val_ap: 0.6920
# Experiment 10 - 51/200 val_roc: 0.7271 val_ap: 0.7264
# Experiment 10 - 101/200 val_roc: 0.7747 val_ap: 0.7716
# Experiment 10 - 151/200 val_roc: 0.8354 val_ap: 0.8273
# Experiment 10 result - ROC(AUC) score: 0.83356, AP score: 0.84427
# All experiments finished!
# Elapsed time: 103.61s
# End time: 2021-12-23 17:17:48
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:17:48
# 3   experiment mode      k-th order sampling mode(n_diff=2, alpha=0.5)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.8831450802760965, 0.8926831551620464, 0.869...
# 8          roc_mean                                           0.870174
# 9           roc_std                                          0.0218834
# 10               ap  [0.8970929446413142, 0.9035824457979648, 0.891...
# 11          ap_mean                                           0.876699
# 12           ap_std                                          0.0265763
# 13  elapsed time(s)                                            103.609
# Last data saved at: 2021-12-23 17:17:48
# Total data num: 83
# Dataset: cora
# Simdiff_params: n_diff =  2, alpha = 0.7
# Start time: 2021-12-23 17:17:48
# Experiment 1 - 1/200 val_roc: 0.7327 val_ap: 0.7477
# Experiment 1 - 51/200 val_roc: 0.7588 val_ap: 0.7501
# Experiment 1 - 101/200 val_roc: 0.7417 val_ap: 0.7496
# Experiment 1 - 151/200 val_roc: 0.7852 val_ap: 0.7863
# Experiment 1 result - ROC(AUC) score: 0.79221, AP score: 0.7983
# Experiment 2 - 1/200 val_roc: 0.6931 val_ap: 0.6987
# Experiment 2 - 51/200 val_roc: 0.7210 val_ap: 0.7178
# Experiment 2 - 101/200 val_roc: 0.7506 val_ap: 0.7435
# Experiment 2 - 151/200 val_roc: 0.7728 val_ap: 0.7695
# Experiment 2 result - ROC(AUC) score: 0.80089, AP score: 0.7895
# Experiment 3 - 1/200 val_roc: 0.7056 val_ap: 0.6945
# Experiment 3 - 51/200 val_roc: 0.7239 val_ap: 0.7050
# Experiment 3 - 101/200 val_roc: 0.7636 val_ap: 0.7709
# Experiment 3 - 151/200 val_roc: 0.7996 val_ap: 0.8085
# Experiment 3 result - ROC(AUC) score: 0.81154, AP score: 0.82046
# Experiment 4 - 1/200 val_roc: 0.7238 val_ap: 0.7120
# Experiment 4 - 51/200 val_roc: 0.8270 val_ap: 0.8343
# Experiment 4 - 101/200 val_roc: 0.8511 val_ap: 0.8617
# Experiment 4 - 151/200 val_roc: 0.8517 val_ap: 0.8646
# Experiment 4 result - ROC(AUC) score: 0.87758, AP score: 0.8902
# Experiment 5 - 1/200 val_roc: 0.7019 val_ap: 0.7123
# Experiment 5 - 51/200 val_roc: 0.8282 val_ap: 0.8292
# Experiment 5 - 101/200 val_roc: 0.8640 val_ap: 0.8699
# Experiment 5 - 151/200 val_roc: 0.8792 val_ap: 0.8839
# Experiment 5 result - ROC(AUC) score: 0.87114, AP score: 0.86999
# Experiment 6 - 1/200 val_roc: 0.7609 val_ap: 0.7760
# Experiment 6 - 51/200 val_roc: 0.7806 val_ap: 0.7877
# Experiment 6 - 101/200 val_roc: 0.8157 val_ap: 0.8153
# Experiment 6 - 151/200 val_roc: 0.8373 val_ap: 0.8364
# Experiment 6 result - ROC(AUC) score: 0.81698, AP score: 0.82828
# Experiment 7 - 1/200 val_roc: 0.6827 val_ap: 0.6880
# Experiment 7 - 51/200 val_roc: 0.8030 val_ap: 0.8212
# Experiment 7 - 101/200 val_roc: 0.8255 val_ap: 0.8413
# Experiment 7 - 151/200 val_roc: 0.8381 val_ap: 0.8485
# Experiment 7 result - ROC(AUC) score: 0.85859, AP score: 0.87377
# Experiment 8 - 1/200 val_roc: 0.6955 val_ap: 0.6846
# Experiment 8 - 51/200 val_roc: 0.8438 val_ap: 0.8520
# Experiment 8 - 101/200 val_roc: 0.8749 val_ap: 0.8856
# Experiment 8 - 151/200 val_roc: 0.8932 val_ap: 0.9010
# Experiment 8 result - ROC(AUC) score: 0.88846, AP score: 0.90161
# Experiment 9 - 1/200 val_roc: 0.7045 val_ap: 0.7148
# Experiment 9 - 51/200 val_roc: 0.7055 val_ap: 0.6991
# Experiment 9 - 101/200 val_roc: 0.7351 val_ap: 0.7254
# Experiment 9 - 151/200 val_roc: 0.7604 val_ap: 0.7513
# Experiment 9 result - ROC(AUC) score: 0.81697, AP score: 0.81631
# Experiment 10 - 1/200 val_roc: 0.7213 val_ap: 0.7289
# Experiment 10 - 51/200 val_roc: 0.7492 val_ap: 0.7659
# Experiment 10 - 101/200 val_roc: 0.8106 val_ap: 0.8204
# Experiment 10 - 151/200 val_roc: 0.8353 val_ap: 0.8424
# Experiment 10 result - ROC(AUC) score: 0.85026, AP score: 0.85946
# All experiments finished!
# Elapsed time: 103.61s
# End time: 2021-12-23 17:19:31
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:19:31
# 3   experiment mode      k-th order sampling mode(n_diff=2, alpha=0.7)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.7922147129035859, 0.8008886360444896, 0.811...
# 8          roc_mean                                           0.838462
# 9           roc_std                                          0.0329257
# 10               ap  [0.7983024414450405, 0.7894951642046861, 0.820...
# 11          ap_mean                                           0.844786
# 12           ap_std                                          0.0372491
# 13  elapsed time(s)                                            103.606
# Last data saved at: 2021-12-23 17:19:31
# Total data num: 84
# Dataset: cora
# Simdiff_params: n_diff =  2, alpha = 0.9
# Start time: 2021-12-23 17:19:31
# Experiment 1 - 1/200 val_roc: 0.6988 val_ap: 0.6826
# Experiment 1 - 51/200 val_roc: 0.8027 val_ap: 0.8022
# Experiment 1 - 101/200 val_roc: 0.8585 val_ap: 0.8656
# Experiment 1 - 151/200 val_roc: 0.8726 val_ap: 0.8874
# Experiment 1 result - ROC(AUC) score: 0.86241, AP score: 0.85705
# Experiment 2 - 1/200 val_roc: 0.7155 val_ap: 0.7457
# Experiment 2 - 51/200 val_roc: 0.8207 val_ap: 0.8273
# Experiment 2 - 101/200 val_roc: 0.8686 val_ap: 0.8754
# Experiment 2 - 151/200 val_roc: 0.8741 val_ap: 0.8792
# Experiment 2 result - ROC(AUC) score: 0.86827, AP score: 0.88059
# Experiment 3 - 1/200 val_roc: 0.6708 val_ap: 0.6839
# Experiment 3 - 51/200 val_roc: 0.7315 val_ap: 0.7526
# Experiment 3 - 101/200 val_roc: 0.8285 val_ap: 0.8216
# Experiment 3 - 151/200 val_roc: 0.8725 val_ap: 0.8699
# Experiment 3 result - ROC(AUC) score: 0.85703, AP score: 0.85949
# Experiment 4 - 1/200 val_roc: 0.6990 val_ap: 0.7044
# Experiment 4 - 51/200 val_roc: 0.8130 val_ap: 0.8187
# Experiment 4 - 101/200 val_roc: 0.8555 val_ap: 0.8549
# Experiment 4 - 151/200 val_roc: 0.8639 val_ap: 0.8615
# Experiment 4 result - ROC(AUC) score: 0.85814, AP score: 0.85738
# Experiment 5 - 1/200 val_roc: 0.7463 val_ap: 0.7233
# Experiment 5 - 51/200 val_roc: 0.7787 val_ap: 0.7636
# Experiment 5 - 101/200 val_roc: 0.8368 val_ap: 0.8298
# Experiment 5 - 151/200 val_roc: 0.8537 val_ap: 0.8405
# Experiment 5 result - ROC(AUC) score: 0.86629, AP score: 0.87596
# Experiment 6 - 1/200 val_roc: 0.7195 val_ap: 0.7104
# Experiment 6 - 51/200 val_roc: 0.7613 val_ap: 0.7696
# Experiment 6 - 101/200 val_roc: 0.7750 val_ap: 0.7874
# Experiment 6 - 151/200 val_roc: 0.7897 val_ap: 0.7999
# Experiment 6 result - ROC(AUC) score: 0.81856, AP score: 0.82225
# Experiment 7 - 1/200 val_roc: 0.6734 val_ap: 0.6779
# Experiment 7 - 51/200 val_roc: 0.5750 val_ap: 0.5909
# Experiment 7 - 101/200 val_roc: 0.6174 val_ap: 0.6486
# Experiment 7 - 151/200 val_roc: 0.7529 val_ap: 0.7497
# Experiment 7 result - ROC(AUC) score: 0.79349, AP score: 0.81271
# Experiment 8 - 1/200 val_roc: 0.7196 val_ap: 0.7133
# Experiment 8 - 51/200 val_roc: 0.8058 val_ap: 0.8179
# Experiment 8 - 101/200 val_roc: 0.8241 val_ap: 0.8275
# Experiment 8 - 151/200 val_roc: 0.8351 val_ap: 0.8477
# Experiment 8 result - ROC(AUC) score: 0.85865, AP score: 0.87187
# Experiment 9 - 1/200 val_roc: 0.7271 val_ap: 0.7478
# Experiment 9 - 51/200 val_roc: 0.8330 val_ap: 0.8358
# Experiment 9 - 101/200 val_roc: 0.8632 val_ap: 0.8658
# Experiment 9 - 151/200 val_roc: 0.8706 val_ap: 0.8786
# Experiment 9 result - ROC(AUC) score: 0.8671, AP score: 0.88075
# Experiment 10 - 1/200 val_roc: 0.7337 val_ap: 0.7291
# Experiment 10 - 51/200 val_roc: 0.8395 val_ap: 0.8396
# Experiment 10 - 101/200 val_roc: 0.8578 val_ap: 0.8602
# Experiment 10 - 151/200 val_roc: 0.8727 val_ap: 0.8676
# Experiment 10 result - ROC(AUC) score: 0.85853, AP score: 0.87039
# All experiments finished!
# Elapsed time: 103.80s
# End time: 2021-12-23 17:21:15
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:21:15
# 3   experiment mode      k-th order sampling mode(n_diff=2, alpha=0.9)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.862405438394982, 0.8682744689967559, 0.8570...
# 8          roc_mean                                           0.850847
# 9           roc_std                                          0.0234183
# 10               ap  [0.8570528576313261, 0.8805886044108208, 0.859...
# 11          ap_mean                                           0.858844
# 12           ap_std                                          0.0224097
# 13  elapsed time(s)                                            103.796
# Last data saved at: 2021-12-23 17:21:15
# Total data num: 85
# Dataset: cora
# Simdiff_params: n_diff =  3, alpha = 0.1
# Start time: 2021-12-23 17:21:15
# Experiment 1 - 1/200 val_roc: 0.6404 val_ap: 0.6229
# Experiment 1 - 51/200 val_roc: 0.6115 val_ap: 0.5901
# Experiment 1 - 101/200 val_roc: 0.6365 val_ap: 0.6115
# Experiment 1 - 151/200 val_roc: 0.6751 val_ap: 0.6615
# Experiment 1 result - ROC(AUC) score: 0.7143, AP score: 0.68942
# Experiment 2 - 1/200 val_roc: 0.6607 val_ap: 0.6533
# Experiment 2 - 51/200 val_roc: 0.6583 val_ap: 0.6713
# Experiment 2 - 101/200 val_roc: 0.6569 val_ap: 0.6580
# Experiment 2 - 151/200 val_roc: 0.6833 val_ap: 0.6698
# Experiment 2 result - ROC(AUC) score: 0.70274, AP score: 0.67107
# Experiment 3 - 1/200 val_roc: 0.7033 val_ap: 0.6976
# Experiment 3 - 51/200 val_roc: 0.6365 val_ap: 0.6357
# Experiment 3 - 101/200 val_roc: 0.5841 val_ap: 0.5949
# Experiment 3 - 151/200 val_roc: 0.5941 val_ap: 0.6084
# Experiment 3 result - ROC(AUC) score: 0.59247, AP score: 0.60203
# Experiment 4 - 1/200 val_roc: 0.5807 val_ap: 0.5588
# Experiment 4 - 51/200 val_roc: 0.6154 val_ap: 0.5878
# Experiment 4 - 101/200 val_roc: 0.5991 val_ap: 0.5766
# Experiment 4 - 151/200 val_roc: 0.6055 val_ap: 0.5876
# Experiment 4 result - ROC(AUC) score: 0.654, AP score: 0.64672
# Experiment 5 - 1/200 val_roc: 0.6637 val_ap: 0.6223
# Experiment 5 - 51/200 val_roc: 0.5656 val_ap: 0.5638
# Experiment 5 - 101/200 val_roc: 0.5784 val_ap: 0.5679
# Experiment 5 - 151/200 val_roc: 0.6170 val_ap: 0.5966
# Experiment 5 result - ROC(AUC) score: 0.68488, AP score: 0.67217
# Experiment 6 - 1/200 val_roc: 0.6259 val_ap: 0.6427
# Experiment 6 - 51/200 val_roc: 0.6855 val_ap: 0.6870
# Experiment 6 - 101/200 val_roc: 0.6910 val_ap: 0.6970
# Experiment 6 - 151/200 val_roc: 0.7754 val_ap: 0.7925
# Experiment 6 result - ROC(AUC) score: 0.80065, AP score: 0.80605
# Experiment 7 - 1/200 val_roc: 0.6213 val_ap: 0.5969
# Experiment 7 - 51/200 val_roc: 0.6544 val_ap: 0.6455
# Experiment 7 - 101/200 val_roc: 0.7008 val_ap: 0.6751
# Experiment 7 - 151/200 val_roc: 0.7731 val_ap: 0.7471
# Experiment 7 result - ROC(AUC) score: 0.78458, AP score: 0.76902
# Experiment 8 - 1/200 val_roc: 0.6614 val_ap: 0.6460
# Experiment 8 - 51/200 val_roc: 0.6772 val_ap: 0.6833
# Experiment 8 - 101/200 val_roc: 0.6541 val_ap: 0.6529
# Experiment 8 - 151/200 val_roc: 0.6777 val_ap: 0.6724
# Experiment 8 result - ROC(AUC) score: 0.70477, AP score: 0.70722
# Experiment 9 - 1/200 val_roc: 0.6443 val_ap: 0.6340
# Experiment 9 - 51/200 val_roc: 0.6887 val_ap: 0.6990
# Experiment 9 - 101/200 val_roc: 0.6576 val_ap: 0.6694
# Experiment 9 - 151/200 val_roc: 0.6569 val_ap: 0.6608
# Experiment 9 result - ROC(AUC) score: 0.64695, AP score: 0.65022
# Experiment 10 - 1/200 val_roc: 0.6069 val_ap: 0.5927
# Experiment 10 - 51/200 val_roc: 0.6569 val_ap: 0.6402
# Experiment 10 - 101/200 val_roc: 0.7494 val_ap: 0.7242
# Experiment 10 - 151/200 val_roc: 0.7942 val_ap: 0.7748
# Experiment 10 result - ROC(AUC) score: 0.81448, AP score: 0.80688
# All experiments finished!
# Elapsed time: 114.00s
# End time: 2021-12-23 17:23:09
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:23:09
# 3   experiment mode      k-th order sampling mode(n_diff=3, alpha=0.1)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.7143006311908372, 0.70273900096857, 0.59247...
# 8          roc_mean                                           0.709982
# 9           roc_std                                            0.06808
# 10               ap  [0.6894171121995807, 0.6710733456185006, 0.602...
# 11          ap_mean                                           0.702079
# 12           ap_std                                           0.066394
# 13  elapsed time(s)                                            113.998
# Last data saved at: 2021-12-23 17:23:09
# Total data num: 86
# Dataset: cora
# Simdiff_params: n_diff =  3, alpha = 0.3
# Start time: 2021-12-23 17:23:09
# Experiment 1 - 1/200 val_roc: 0.7033 val_ap: 0.6919
# Experiment 1 - 51/200 val_roc: 0.6762 val_ap: 0.6872
# Experiment 1 - 101/200 val_roc: 0.7139 val_ap: 0.7293
# Experiment 1 - 151/200 val_roc: 0.7620 val_ap: 0.7793
# Experiment 1 result - ROC(AUC) score: 0.78182, AP score: 0.78394
# Experiment 2 - 1/200 val_roc: 0.6719 val_ap: 0.6679
# Experiment 2 - 51/200 val_roc: 0.7071 val_ap: 0.7197
# Experiment 2 - 101/200 val_roc: 0.7665 val_ap: 0.7910
# Experiment 2 - 151/200 val_roc: 0.8068 val_ap: 0.8221
# Experiment 2 result - ROC(AUC) score: 0.81337, AP score: 0.82015
# Experiment 3 - 1/200 val_roc: 0.6809 val_ap: 0.6915
# Experiment 3 - 51/200 val_roc: 0.6838 val_ap: 0.6624
# Experiment 3 - 101/200 val_roc: 0.7129 val_ap: 0.6713
# Experiment 3 - 151/200 val_roc: 0.7284 val_ap: 0.6923
# Experiment 3 result - ROC(AUC) score: 0.71286, AP score: 0.68237
# Experiment 4 - 1/200 val_roc: 0.6929 val_ap: 0.6963
# Experiment 4 - 51/200 val_roc: 0.7831 val_ap: 0.7763
# Experiment 4 - 101/200 val_roc: 0.7747 val_ap: 0.7688
# Experiment 4 - 151/200 val_roc: 0.7614 val_ap: 0.7612
# Experiment 4 result - ROC(AUC) score: 0.73968, AP score: 0.74459
# Experiment 5 - 1/200 val_roc: 0.7415 val_ap: 0.7656
# Experiment 5 - 51/200 val_roc: 0.6963 val_ap: 0.7302
# Experiment 5 - 101/200 val_roc: 0.7689 val_ap: 0.8096
# Experiment 5 - 151/200 val_roc: 0.8138 val_ap: 0.8516
# Experiment 5 result - ROC(AUC) score: 0.85602, AP score: 0.86243
# Experiment 6 - 1/200 val_roc: 0.6497 val_ap: 0.6824
# Experiment 6 - 51/200 val_roc: 0.7030 val_ap: 0.7106
# Experiment 6 - 101/200 val_roc: 0.7232 val_ap: 0.7317
# Experiment 6 - 151/200 val_roc: 0.7487 val_ap: 0.7516
# Experiment 6 result - ROC(AUC) score: 0.80737, AP score: 0.79977
# Experiment 7 - 1/200 val_roc: 0.6975 val_ap: 0.7034
# Experiment 7 - 51/200 val_roc: 0.5019 val_ap: 0.5009
# Experiment 7 - 101/200 val_roc: 0.7299 val_ap: 0.7466
# Experiment 7 - 151/200 val_roc: 0.7241 val_ap: 0.7027
# Experiment 7 result - ROC(AUC) score: 0.73339, AP score: 0.72121
# Experiment 8 - 1/200 val_roc: 0.6675 val_ap: 0.6576
# Experiment 8 - 51/200 val_roc: 0.7038 val_ap: 0.6530
# Experiment 8 - 101/200 val_roc: 0.8329 val_ap: 0.8170
# Experiment 8 - 151/200 val_roc: 0.8434 val_ap: 0.8354
# Experiment 8 result - ROC(AUC) score: 0.82241, AP score: 0.82281
# Experiment 9 - 1/200 val_roc: 0.7008 val_ap: 0.6815
# Experiment 9 - 51/200 val_roc: 0.6739 val_ap: 0.6654
# Experiment 9 - 101/200 val_roc: 0.6776 val_ap: 0.6644
# Experiment 9 - 151/200 val_roc: 0.6978 val_ap: 0.6874
# Experiment 9 result - ROC(AUC) score: 0.73423, AP score: 0.74264
# Experiment 10 - 1/200 val_roc: 0.6782 val_ap: 0.6929
# Experiment 10 - 51/200 val_roc: 0.7156 val_ap: 0.7061
# Experiment 10 - 101/200 val_roc: 0.7061 val_ap: 0.7174
# Experiment 10 - 151/200 val_roc: 0.7550 val_ap: 0.7660
# Experiment 10 result - ROC(AUC) score: 0.76006, AP score: 0.76188
# All experiments finished!
# Elapsed time: 115.52s
# End time: 2021-12-23 17:25:05
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# ...
# Experiment 1 - 151/200 val_roc: 0.5133 val_ap: 0.5067
# Experiment 1 result - ROC(AUC) score: 0.52562, AP score: 0.51315
# Experiment 2 - 1/200 val_roc: 0.6635 val_ap: 0.6080
# Experiment 2 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 2 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 2 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 2 result - ROC(AUC) score: 0.5, AP score: 0.5
# Experiment 3 - 1/200 val_roc: 0.7060 val_ap: 0.6851
# Experiment 3 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 3 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 3 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 3 result - ROC(AUC) score: 0.5, AP score: 0.5
# Experiment 4 - 1/200 val_roc: 0.6838 val_ap: 0.6348
# Experiment 4 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 4 - 101/200 val_roc: 0.5019 val_ap: 0.5010
# Experiment 4 - 151/200 val_roc: 0.5342 val_ap: 0.5179
# Experiment 4 result - ROC(AUC) score: 0.58313, AP score: 0.54659
# Experiment 5 - 1/200 val_roc: 0.5766 val_ap: 0.5431
# Experiment 5 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 5 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 5 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 5 result - ROC(AUC) score: 0.5, AP score: 0.5
# Experiment 6 - 1/200 val_roc: 0.6788 val_ap: 0.6281
# Experiment 6 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 6 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 6 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 6 result - ROC(AUC) score: 0.5, AP score: 0.5
# Experiment 7 - 1/200 val_roc: 0.6790 val_ap: 0.6329
# Experiment 7 - 51/200 val_roc: 0.5247 val_ap: 0.5127
# Experiment 7 - 101/200 val_roc: 0.5973 val_ap: 0.5541
# Experiment 7 - 151/200 val_roc: 0.6036 val_ap: 0.5583
# Experiment 7 result - ROC(AUC) score: 0.64432, AP score: 0.58539
# Experiment 8 - 1/200 val_roc: 0.5038 val_ap: 0.5019
# Experiment 8 - 51/200 val_roc: 0.4981 val_ap: 0.4991
# Experiment 8 - 101/200 val_roc: 0.4981 val_ap: 0.4991
# Experiment 8 - 151/200 val_roc: 0.4981 val_ap: 0.4991
# Experiment 8 result - ROC(AUC) score: 0.50095, AP score: 0.50047
# Experiment 9 - 1/200 val_roc: 0.6972 val_ap: 0.6475
# Experiment 9 - 51/200 val_roc: 0.5115 val_ap: 0.5058
# Experiment 9 - 101/200 val_roc: 0.5551 val_ap: 0.5292
# Experiment 9 - 151/200 val_roc: 0.5665 val_ap: 0.5358
# Experiment 9 result - ROC(AUC) score: 0.56262, AP score: 0.53357
# Experiment 10 - 1/200 val_roc: 0.5225 val_ap: 0.5119
# Experiment 10 - 51/200 val_roc: 0.5019 val_ap: 0.5010
# Experiment 10 - 101/200 val_roc: 0.5114 val_ap: 0.5058
# Experiment 10 - 151/200 val_roc: 0.5228 val_ap: 0.5117
# Experiment 10 result - ROC(AUC) score: 0.51803, AP score: 0.50918
# All experiments finished!
# Elapsed time: 177.17s
# End time: 2021-12-23 17:48:34
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:48:34
# 3   experiment mode      k-th order sampling mode(n_diff=5, alpha=0.3)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.5256166982922201, 0.5, 0.4999981996838645, ...
# 8          roc_mean                                           0.533466
# 9           roc_std                                          0.0463051
# 10               ap  [0.5131497365369737, 0.5, 0.5, 0.5465924543705...
# 11          ap_mean                                           0.518836
# 12           ap_std                                          0.0270163
# 13  elapsed time(s)                                            177.165
# Last data saved at: 2021-12-23 17:48:34
# Total data num: 97
# Dataset: cora
# Simdiff_params: n_diff =  5, alpha = 0.5
# Start time: 2021-12-23 17:48:34
# Experiment 1 - 1/200 val_roc: 0.5617 val_ap: 0.5347
# Experiment 1 - 51/200 val_roc: 0.5038 val_ap: 0.5019
# Experiment 1 - 101/200 val_roc: 0.8094 val_ap: 0.7947
# Experiment 1 - 151/200 val_roc: 0.8164 val_ap: 0.8107
# Experiment 1 result - ROC(AUC) score: 0.78574, AP score: 0.7708
# Experiment 2 - 1/200 val_roc: 0.6794 val_ap: 0.6317
# Experiment 2 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 2 - 101/200 val_roc: 0.5323 val_ap: 0.5170
# Experiment 2 - 151/200 val_roc: 0.6025 val_ap: 0.5586
# Experiment 2 result - ROC(AUC) score: 0.61461, AP score: 0.56592
# Experiment 3 - 1/200 val_roc: 0.6435 val_ap: 0.5954
# Experiment 3 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 3 - 101/200 val_roc: 0.5019 val_ap: 0.5010
# Experiment 3 - 151/200 val_roc: 0.5019 val_ap: 0.5010
# Experiment 3 result - ROC(AUC) score: 0.49905, AP score: 0.49953
# Experiment 4 - 1/200 val_roc: 0.6470 val_ap: 0.6033
# Experiment 4 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 4 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 4 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 4 result - ROC(AUC) score: 0.5, AP score: 0.5
# Experiment 5 - 1/200 val_roc: 0.6579 val_ap: 0.6112
# Experiment 5 - 51/200 val_roc: 0.5001 val_ap: 0.5000
# Experiment 5 - 101/200 val_roc: 0.5097 val_ap: 0.5049
# Experiment 5 - 151/200 val_roc: 0.5537 val_ap: 0.5290
# Experiment 5 result - ROC(AUC) score: 0.67579, AP score: 0.6194
# Experiment 6 - 1/200 val_roc: 0.6889 val_ap: 0.6282
# Experiment 6 - 51/200 val_roc: 0.5760 val_ap: 0.5412
# Experiment 6 - 101/200 val_roc: 0.5778 val_ap: 0.5424
# Experiment 6 - 151/200 val_roc: 0.6000 val_ap: 0.5563
# Experiment 6 result - ROC(AUC) score: 0.60272, AP score: 0.55879
# Experiment 7 - 1/200 val_roc: 0.7402 val_ap: 0.7253
# Experiment 7 - 51/200 val_roc: 0.5019 val_ap: 0.5009
# Experiment 7 - 101/200 val_roc: 0.5076 val_ap: 0.5038
# Experiment 7 - 151/200 val_roc: 0.5076 val_ap: 0.5038
# Experiment 7 result - ROC(AUC) score: 0.49452, AP score: 0.49717
# Experiment 8 - 1/200 val_roc: 0.7546 val_ap: 0.7088
# Experiment 8 - 51/200 val_roc: 0.5095 val_ap: 0.5048
# Experiment 8 - 101/200 val_roc: 0.5153 val_ap: 0.5078
# Experiment 8 - 151/200 val_roc: 0.5305 val_ap: 0.5158
# Experiment 8 result - ROC(AUC) score: 0.54171, AP score: 0.52212
# Experiment 9 - 1/200 val_roc: 0.6738 val_ap: 0.6363
# Experiment 9 - 51/200 val_roc: 0.4981 val_ap: 0.4991
# Experiment 9 - 101/200 val_roc: 0.4962 val_ap: 0.4981
# Experiment 9 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 9 result - ROC(AUC) score: 0.51146, AP score: 0.50577
# Experiment 10 - 1/200 val_roc: 0.7199 val_ap: 0.6732
# Experiment 10 - 51/200 val_roc: 0.5152 val_ap: 0.5078
# Experiment 10 - 101/200 val_roc: 0.8061 val_ap: 0.7832
# Experiment 10 - 151/200 val_roc: 0.8070 val_ap: 0.7909
# Experiment 10 result - ROC(AUC) score: 0.79974, AP score: 0.78348
# All experiments finished!
# Elapsed time: 175.99s
# End time: 2021-12-23 17:51:30
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:51:30
# 3   experiment mode      k-th order sampling mode(n_diff=5, alpha=0.5)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.7857389757641442, 0.6146135261351893, 0.499...
# 8          roc_mean                                           0.602534
# 9           roc_std                                           0.110838
# 10               ap  [0.7708022712835084, 0.5659200387749534, 0.499...
# 11          ap_mean                                           0.582297
# 12           ap_std                                           0.104189
# 13  elapsed time(s)                                            175.992
# Last data saved at: 2021-12-23 17:51:30
# Total data num: 98
# Dataset: cora
# Simdiff_params: n_diff =  5, alpha = 0.7
# Start time: 2021-12-23 17:51:30
# Experiment 1 - 1/200 val_roc: 0.7213 val_ap: 0.6794
# Experiment 1 - 51/200 val_roc: 0.5455 val_ap: 0.5242
# Experiment 1 - 101/200 val_roc: 0.6211 val_ap: 0.5717
# Experiment 1 - 151/200 val_roc: 0.6588 val_ap: 0.5996
# Experiment 1 result - ROC(AUC) score: 0.69286, AP score: 0.63332
# Experiment 2 - 1/200 val_roc: 0.6982 val_ap: 0.6700
# Experiment 2 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 2 - 101/200 val_roc: 0.5058 val_ap: 0.5029
# Experiment 2 - 151/200 val_roc: 0.5056 val_ap: 0.5029
# Experiment 2 result - ROC(AUC) score: 0.51325, AP score: 0.50673
# Experiment 3 - 1/200 val_roc: 0.6749 val_ap: 0.6198
# Experiment 3 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 3 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 3 - 151/200 val_roc: 0.4981 val_ap: 0.4991
# Experiment 3 result - ROC(AUC) score: 0.49999, AP score: 0.5
# Experiment 4 - 1/200 val_roc: 0.6608 val_ap: 0.6112
# Experiment 4 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 4 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 4 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 4 result - ROC(AUC) score: 0.50187, AP score: 0.50095
# Experiment 5 - 1/200 val_roc: 0.5570 val_ap: 0.5316
# Experiment 5 - 51/200 val_roc: 0.5664 val_ap: 0.5359
# Experiment 5 - 101/200 val_roc: 0.5875 val_ap: 0.5484
# Experiment 5 - 151/200 val_roc: 0.5918 val_ap: 0.5510
# Experiment 5 result - ROC(AUC) score: 0.5976, AP score: 0.55489
# Experiment 6 - 1/200 val_roc: 0.6491 val_ap: 0.6029
# Experiment 6 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 6 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 6 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 6 result - ROC(AUC) score: 0.5, AP score: 0.5
# Experiment 7 - 1/200 val_roc: 0.7612 val_ap: 0.7536
# Experiment 7 - 51/200 val_roc: 0.7097 val_ap: 0.6487
# Experiment 7 - 101/200 val_roc: 0.8058 val_ap: 0.7928
# Experiment 7 - 151/200 val_roc: 0.8015 val_ap: 0.7877
# Experiment 7 result - ROC(AUC) score: 0.79061, AP score: 0.77653
# Experiment 8 - 1/200 val_roc: 0.7177 val_ap: 0.6564
# Experiment 8 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 8 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 8 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 8 result - ROC(AUC) score: 0.5, AP score: 0.5
# Experiment 9 - 1/200 val_roc: 0.7219 val_ap: 0.6856
# Experiment 9 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 9 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 9 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 9 result - ROC(AUC) score: 0.5, AP score: 0.5
# Experiment 10 - 1/200 val_roc: 0.7618 val_ap: 0.7410
# Experiment 10 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 10 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 10 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 10 result - ROC(AUC) score: 0.5, AP score: 0.5
# All experiments finished!
# Elapsed time: 170.72s
# End time: 2021-12-23 17:54:21
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:54:21
# 3   experiment mode      k-th order sampling mode(n_diff=5, alpha=0.7)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.6928606663330081, 0.5132539273896496, 0.499...
# 8          roc_mean                                           0.559618
# 9           roc_std                                          0.0978826
# 10               ap  [0.633317250254715, 0.5067336074214632, 0.4999...
# 11          ap_mean                                           0.547242
# 12           ap_std                                          0.0865936
# 13  elapsed time(s)                                            170.719
# Last data saved at: 2021-12-23 17:54:21
# Total data num: 99
# Dataset: cora
# Simdiff_params: n_diff =  5, alpha = 0.9
# Start time: 2021-12-23 17:54:21
# Experiment 1 - 1/200 val_roc: 0.6844 val_ap: 0.6524
# Experiment 1 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 1 - 101/200 val_roc: 0.4981 val_ap: 0.4991
# Experiment 1 - 151/200 val_roc: 0.4981 val_ap: 0.4991
# Experiment 1 result - ROC(AUC) score: 0.49904, AP score: 0.49952
# Experiment 2 - 1/200 val_roc: 0.7051 val_ap: 0.6550
# Experiment 2 - 51/200 val_roc: 0.5629 val_ap: 0.5339
# Experiment 2 - 101/200 val_roc: 0.8204 val_ap: 0.7957
# Experiment 2 - 151/200 val_roc: 0.8199 val_ap: 0.7921
# Experiment 2 result - ROC(AUC) score: 0.79445, AP score: 0.76972
# Experiment 3 - 1/200 val_roc: 0.7982 val_ap: 0.7600
# Experiment 3 - 51/200 val_roc: 0.6129 val_ap: 0.5640
# Experiment 3 - 101/200 val_roc: 0.6331 val_ap: 0.5786
# Experiment 3 - 151/200 val_roc: 0.6271 val_ap: 0.5745
# Experiment 3 result - ROC(AUC) score: 0.65026, AP score: 0.5932
# Experiment 4 - 1/200 val_roc: 0.7461 val_ap: 0.7403
# Experiment 4 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 4 - 101/200 val_roc: 0.5019 val_ap: 0.5010
# Experiment 4 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 4 result - ROC(AUC) score: 0.52066, AP score: 0.51071
# Experiment 5 - 1/200 val_roc: 0.6942 val_ap: 0.6677
# Experiment 5 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 5 - 101/200 val_roc: 0.4980 val_ap: 0.4991
# Experiment 5 - 151/200 val_roc: 0.5076 val_ap: 0.5038
# Experiment 5 result - ROC(AUC) score: 0.50095, AP score: 0.50047
# Experiment 6 - 1/200 val_roc: 0.5818 val_ap: 0.5478
# Experiment 6 - 51/200 val_roc: 0.8020 val_ap: 0.7824
# Experiment 6 - 101/200 val_roc: 0.8057 val_ap: 0.7866
# Experiment 6 - 151/200 val_roc: 0.8083 val_ap: 0.7887
# Experiment 6 result - ROC(AUC) score: 0.79583, AP score: 0.78455
# Experiment 7 - 1/200 val_roc: 0.6733 val_ap: 0.6334
# Experiment 7 - 51/200 val_roc: 0.4981 val_ap: 0.4991
# Experiment 7 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 7 - 151/200 val_roc: 0.4981 val_ap: 0.4991
# Experiment 7 result - ROC(AUC) score: 0.51518, AP score: 0.50771
# Experiment 8 - 1/200 val_roc: 0.7274 val_ap: 0.6969
# Experiment 8 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 8 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 8 - 151/200 val_roc: 0.5317 val_ap: 0.5168
# Experiment 8 result - ROC(AUC) score: 0.76455, AP score: 0.7383
# Experiment 9 - 1/200 val_roc: 0.6795 val_ap: 0.6318
# Experiment 9 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 9 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 9 - 151/200 val_roc: 0.5019 val_ap: 0.5010
# Experiment 9 result - ROC(AUC) score: 0.4981, AP score: 0.49905
# Experiment 10 - 1/200 val_roc: 0.5939 val_ap: 0.5575
# Experiment 10 - 51/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 10 - 101/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 10 - 151/200 val_roc: 0.5000 val_ap: 0.5000
# Experiment 10 result - ROC(AUC) score: 0.5, AP score: 0.5
# All experiments finished!
# Elapsed time: 163.87s
# End time: 2021-12-23 17:57:05
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                               cora
# 2          datetime                                2021-12-23 17:57:05
# 3   experiment mode      k-th order sampling mode(n_diff=5, alpha=0.9)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.49904403213204235, 0.7944471049116226, 0.65...
# 8          roc_mean                                           0.603902
# 9           roc_std                                           0.126288
# 10               ap  [0.4995242651821831, 0.7697222601617177, 0.593...
# 11          ap_mean                                           0.590325
# 12           ap_std                                           0.117381
# 13  elapsed time(s)                                            163.871
# Last data saved at: 2021-12-23 17:57:05
# Total data num: 100

# %% [markdown]
# ### VGAE(single operation)

# %%
# results = vgae_iter(adj, features, hparams, feature_use=feature_use, n_iter=n_iter)

# %% [markdown]
# ### Save log

# %%
# date = (datetime.now() + timedelta(hours=9)).strftime("%Y-%m-%d %H:%M:%S")
# hparams_add = hparams[:-2] + (feat_norm,) + (feature_use,)
# if n_diff == 1 and alpha == 0.5:
#     experiment_mode = 'normal mode(n_diff={}, alpha={})'.format(n_diff, alpha)
# else:
#     experiment_mode = 'simplified diffusion mode(n_diff={}, alpha={})'.format(n_diff, alpha)

# %%
# log_dict= OrderedDict()

# %%
# log_dict['model'] = model_name
# log_dict['dataset'] = dataset
# log_dict['datetime'] = date
# log_dict['experiment mode'] =  experiment_mode
# log_dict['setting_order'] = ['epochs', 'hidden1', 'hidden2', 'lr', 'dropout', 'test_val_ratio', 'feat_norm', 'feat_use']
# log_dict['setting_value'] = hparams_add
# log_dict['iteration'] = n_iter
# log_dict['roc'] = results[0]
# log_dict['roc_mean'] = np.mean(results[0])
# log_dict['roc_std'] = np.std(results[0])
# log_dict['ap'] = results[1]
# log_dict['ap_mean'] = np.mean(results[1])
# log_dict['ap_std'] = np.std(results[1])
# log_dict['elapsed time(s)'] = np.round(results[2], 4)
# pd.DataFrame(log_dict.items(), columns=['key', 'value'])

# %%
# data = json.load(open('results_link_prediction.json'))
# data.append(log_dict)
# with open('results_link_prediction.json', 'w') as f:
#     json.dump(data, f)
# print("Last data saved at: {}".format((datetime.now() + timedelta(hours=9)).strftime("%Y-%m-%d %H:%M:%S")))
# print("Total data num: {}".format(len(data)))
# Out:
# Last data saved at: 2021-09-03 11:07:55
# Total data num: 12

# %%
# if wanna clear results(be careful!)
# empty = []
# with open('results_link_prediction_rename.json', 'w') as f:
#     json.dump(empty, f)

# %% [markdown]
# ### Define VGAE

# %%
def vgae_iter(adj, features, hparams, feature_use=False, n_iter=1):
    
    epochs, hidden1, hidden2, lr, dropout, test_val_ratio, n_diff, alpha = hparams
    test = 1/test_val_ratio[0]
    val = 1/test_val_ratio[1]
    roc_results = []
    ap_results = []
    start = time.time()
    print("Dataset: {}".format(dataset))
    print("Simdiff_params: n_diff =  {}, alpha = {}".format(n_diff, alpha))
    print("Start time: {}".format((datetime.now() + timedelta(hours=9)).strftime("%Y-%m-%d %H:%M:%S")))
    
    for i in range(n_iter):
        adj_orig = remove_diag(adj)
        while True:
            try:
                adj_train, train_edges, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges(adj, test, val)
            except AssertionError:
                continue
            break
        adj_ = adj_train
        adj_norm = preprocess_graph_diff(adj_, n_diff, alpha)
            
        pos_weight = torch.Tensor([float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()])
        norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)
        
        if feature_use == False:
            features = sp.identity(adj.shape[0])
            features = torch.FloatTensor(np.array(features.todense()))
        n_nodes, feat_dim = features.shape
            
        adj_label = adj_train + sp.eye(adj_train.shape[0])
        adj_label = torch.FloatTensor(adj_label.toarray())
 
        adj_norm, features, adj_label, pos_weight = adj_norm.to(device), features.to(device), adj_label.to(device), pos_weight.to(device)
        
        model = GCN_VAE(feat_dim, hidden1, hidden2, dropout)
        model= model.to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr)
        hidden_emb = None
        
        for epoch in range(epochs):
            model.train()
            optimizer.zero_grad()
            recovered, mu, logvar = model(features, adj_norm)
            while True:
                try:
                    loss = loss_function(preds=recovered, labels=adj_label, mu=mu, logvar=logvar, n_nodes=n_nodes, norm=norm, pos_weight=pos_weight)
                except RuntimeError:
                    continue
                break
            loss.backward()
            cur_loss = loss.item()
            optimizer.step()
 
            hidden_emb = mu.data.cpu().numpy()
            roc_curr, ap_curr = get_roc_score_vgae(hidden_emb, adj_orig, val_edges, val_edges_false)
            if epoch % 50 == 0:
                print('Experiment {} - {}/{} val_roc: {:.4f} val_ap: {:.4f}'.format(i+1, epoch+1, epochs, roc_curr, ap_curr), end='\n', flush=True)
 
        roc_score, ap_score = get_roc_score_vgae(hidden_emb, adj_orig, test_edges, test_edges_false)
        roc_results.append(roc_score)
        ap_results.append(ap_score)
        print('Experiment {} result - ROC(AUC) score: {}, AP score: {}'.format(i+1, np.round(roc_score, 5), np.round(ap_score, 5)), end='\n')
    elapsed_time = time.time()-start
    print('All experiments finished!', '\nElapsed time: {:.2f}s'.format(elapsed_time), end='\n')
    print("End time: {}".format((datetime.now() + timedelta(hours=9)).strftime("%Y-%m-%d %H:%M:%S")))
    return roc_results, ap_results, elapsed_time
