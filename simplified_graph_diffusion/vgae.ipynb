# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# import torch_xla
# import torch_xla.core.xla_model as xm

# %%
from vgae.model import GCN_VAE
from vgae.optimizer import loss_function
from vgae.utils import * 
import numpy as np
import pandas as pd
import scipy.sparse as sp
import torch
from torch import optim
import torch.nn.functional as F
from datetime import datetime, timedelta
import time
import json
from collections import OrderedDict

# %% [markdown]
# ### Settings

# %%
model_name = 'vgae'
dataset = 'pubmed' # 'citeseer', 'cora', 'pubmed', 'arx'
task = 'link_prediction' # 'classification', 'link_prediction'
feature_use = True # option only for link prediction
feat_norm = False
n_iter = 10

# %%
hidden1 = 32
hidden2 = 16
lr = 0.01
dropout = 0.
epochs = 200
test_val_ratio = [0.1, 0.05] # len_test = len_total * test_ratio, len_val = len_total * val_ratio
n_diff_range = [2]
alpha_range = [0.1, 0.3, 0.5, 0.7, 0.9]

# %%
# n_diff = 5
# alpha = 0.5
# hparams = epochs, hidden1, hidden2, lr, dropout, test_val_ratio, n_diff, alpha

# %% [markdown]
# ### Import dataset

# %%
if task == 'link_prediction':
    adj, features = load_data(dataset, task, feat_norm)
elif task == 'classification':
    adj, features, labels = load_data(dataset, task, feat_norm)

# %%
# if dataset == 'pubmed':
#     device = torch.device('cpu')
# else: 
#     device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = xm.xla_device()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### VGAE(iterative operation)

# %%
for n_diff in n_diff_range:
    for alpha in alpha_range:
        
        hparams = epochs, hidden1, hidden2, lr, dropout, test_val_ratio, n_diff, alpha
        
        results = vgae_iter(adj, features, hparams, feature_use=feature_use, n_iter=n_iter)
        
        date = (datetime.now() + timedelta(hours=9)).strftime("%Y-%m-%d %H:%M:%S")
        hparams_add = hparams[:-2] + (feat_norm,) + (feature_use,)
        if n_diff == 1 and alpha == 0.5:
            experiment_mode = 'normal mode(n_diff={}, alpha={})'.format(n_diff, alpha)
        else:
            experiment_mode = 'simplified diffusion mode(n_diff={}, alpha={})'.format(n_diff, alpha)
 
        log_dict= OrderedDict()
        log_dict['model'] = model_name
        log_dict['dataset'] = dataset
        log_dict['datetime'] = date
        log_dict['experiment mode'] =  experiment_mode
        log_dict['setting_order'] = ['epochs', 'hidden1', 'hidden2', 'lr', 'dropout', 'test_val_ratio', 'feat_norm', 'feat_use']
        log_dict['setting_value'] = hparams_add
        log_dict['iteration'] = n_iter
        log_dict['roc'] = results[0]
        log_dict['roc_mean'] = np.mean(results[0])
        log_dict['roc_std'] = np.std(results[0])
        log_dict['ap'] = results[1]
        log_dict['ap_mean'] = np.mean(results[1])
        log_dict['ap_std'] = np.std(results[1])
        log_dict['elapsed time(s)'] = np.round(results[2], 4)
        print(pd.DataFrame(log_dict.items(), columns=['key', 'value']))
 
        data = json.load(open('results_link_prediction.json'))
        data.append(log_dict)
        with open('results_link_prediction.json', 'w') as f:
            json.dump(data, f)
        print("Last data saved at: {}".format((datetime.now() + timedelta(hours=9)).strftime("%Y-%m-%d %H:%M:%S")))
        print("Total data num: {}".format(len(data)))
# Out:
# Dataset: pubmed
# Simdiff_params: n_diff =  2, alpha = 0.1
# Start time: 2021-09-08 23:31:17
# Experiment 1 - 1/200 val_roc: 0.6807 val_ap: 0.6599
# Experiment 1 - 51/200 val_roc: 0.8102 val_ap: 0.8152
# Experiment 1 - 101/200 val_roc: 0.8296 val_ap: 0.8352
# Experiment 1 - 151/200 val_roc: 0.8927 val_ap: 0.8928
# Experiment 1 result - ROC(AUC) score: 0.92514, AP score: 0.92331
# Experiment 2 - 1/200 val_roc: 0.7216 val_ap: 0.7117
# Experiment 2 - 51/200 val_roc: 0.8108 val_ap: 0.8121
# Experiment 2 - 101/200 val_roc: 0.8825 val_ap: 0.8804
# Experiment 2 - 151/200 val_roc: 0.9161 val_ap: 0.9146
# Experiment 2 result - ROC(AUC) score: 0.92653, AP score: 0.92411
# Experiment 3 - 1/200 val_roc: 0.7378 val_ap: 0.7185
# Experiment 3 - 51/200 val_roc: 0.8258 val_ap: 0.8220
# Experiment 3 - 101/200 val_roc: 0.8724 val_ap: 0.8731
# Experiment 3 - 151/200 val_roc: 0.8871 val_ap: 0.8921
# Experiment 3 result - ROC(AUC) score: 0.89644, AP score: 0.89895
# Experiment 4 - 1/200 val_roc: 0.6796 val_ap: 0.6681
# Experiment 4 - 51/200 val_roc: 0.7836 val_ap: 0.7789
# Experiment 4 - 101/200 val_roc: 0.8306 val_ap: 0.8349
# Experiment 4 - 151/200 val_roc: 0.8859 val_ap: 0.8901
# Experiment 4 result - ROC(AUC) score: 0.90978, AP score: 0.90606
# Experiment 5 - 1/200 val_roc: 0.7199 val_ap: 0.7045
# Experiment 5 - 51/200 val_roc: 0.8126 val_ap: 0.8167
# Experiment 5 - 101/200 val_roc: 0.8967 val_ap: 0.8954
# Experiment 5 - 151/200 val_roc: 0.9237 val_ap: 0.9207
# Experiment 5 result - ROC(AUC) score: 0.93844, AP score: 0.93783
# Experiment 6 - 1/200 val_roc: 0.7510 val_ap: 0.7295
# Experiment 6 - 51/200 val_roc: 0.7968 val_ap: 0.8031
# Experiment 6 - 101/200 val_roc: 0.8932 val_ap: 0.8952
# Experiment 6 - 151/200 val_roc: 0.9271 val_ap: 0.9292
# Experiment 6 result - ROC(AUC) score: 0.93699, AP score: 0.93419
# Experiment 7 - 1/200 val_roc: 0.7431 val_ap: 0.7257
# Experiment 7 - 51/200 val_roc: 0.8056 val_ap: 0.8128
# Experiment 7 - 101/200 val_roc: 0.8891 val_ap: 0.8881
# Experiment 7 - 151/200 val_roc: 0.9188 val_ap: 0.9180
# Experiment 7 result - ROC(AUC) score: 0.93932, AP score: 0.93688
# Experiment 8 - 1/200 val_roc: 0.7072 val_ap: 0.7057
# Experiment 8 - 51/200 val_roc: 0.8042 val_ap: 0.8048
# Experiment 8 - 101/200 val_roc: 0.8733 val_ap: 0.8667
# Experiment 8 - 151/200 val_roc: 0.9038 val_ap: 0.8971
# Experiment 8 result - ROC(AUC) score: 0.93007, AP score: 0.92823
# Experiment 9 - 1/200 val_roc: 0.6981 val_ap: 0.6733
# Experiment 9 - 51/200 val_roc: 0.7917 val_ap: 0.7951
# Experiment 9 - 101/200 val_roc: 0.8691 val_ap: 0.8645
# Experiment 9 - 151/200 val_roc: 0.8901 val_ap: 0.8858
# Experiment 9 result - ROC(AUC) score: 0.92305, AP score: 0.92072
# Experiment 10 - 1/200 val_roc: 0.7091 val_ap: 0.7105
# Experiment 10 - 51/200 val_roc: 0.8049 val_ap: 0.8094
# Experiment 10 - 101/200 val_roc: 0.8782 val_ap: 0.8794
# Experiment 10 - 151/200 val_roc: 0.8908 val_ap: 0.8945
# Experiment 10 result - ROC(AUC) score: 0.93283, AP score: 0.9326
# All experiments finished!
# Elapsed time: 3532.16s
# End time: 2021-09-09 00:30:09
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                             pubmed
# 2          datetime                                2021-09-09 00:30:09
# 3   experiment mode     simplified diffusion mode(n_diff=2, alpha=0.1)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.9251405260315526, 0.9265338480235634, 0.896...
# 8          roc_mean                                            0.92586
# 9           roc_std                                          0.0128943
# 10               ap  [0.9233112289061455, 0.9241129452611065, 0.898...
# 11          ap_mean                                           0.924289
# 12           ap_std                                          0.0122985
# 13  elapsed time(s)                                            3532.16
# Last data saved at: 2021-09-09 00:30:09
# Total data num: 196
# Dataset: pubmed
# Simdiff_params: n_diff =  2, alpha = 0.3
# Start time: 2021-09-09 00:30:09
# Experiment 1 - 1/200 val_roc: 0.8088 val_ap: 0.8278
# Experiment 1 - 51/200 val_roc: 0.8426 val_ap: 0.8565
# Experiment 1 - 101/200 val_roc: 0.8474 val_ap: 0.8614
# Experiment 1 - 151/200 val_roc: 0.9039 val_ap: 0.9093
# Experiment 1 result - ROC(AUC) score: 0.93221, AP score: 0.93435
# Experiment 2 - 1/200 val_roc: 0.8266 val_ap: 0.8275
# Experiment 2 - 51/200 val_roc: 0.8410 val_ap: 0.8540
# Experiment 2 - 101/200 val_roc: 0.8960 val_ap: 0.9040
# Experiment 2 - 151/200 val_roc: 0.9222 val_ap: 0.9304
# Experiment 2 result - ROC(AUC) score: 0.93778, AP score: 0.94148
# Experiment 3 - 1/200 val_roc: 0.8365 val_ap: 0.8355
# Experiment 3 - 51/200 val_roc: 0.8347 val_ap: 0.8481
# Experiment 3 - 101/200 val_roc: 0.8967 val_ap: 0.9024
# Experiment 3 - 151/200 val_roc: 0.9125 val_ap: 0.9182
# Experiment 3 result - ROC(AUC) score: 0.91301, AP score: 0.92065
# Experiment 4 - 1/200 val_roc: 0.8170 val_ap: 0.8238
# Experiment 4 - 51/200 val_roc: 0.8623 val_ap: 0.8652
# Experiment 4 - 101/200 val_roc: 0.8641 val_ap: 0.8737
# Experiment 4 - 151/200 val_roc: 0.9147 val_ap: 0.9195
# Experiment 4 result - ROC(AUC) score: 0.92969, AP score: 0.93536
# Experiment 5 - 1/200 val_roc: 0.8210 val_ap: 0.8323
# Experiment 5 - 51/200 val_roc: 0.9010 val_ap: 0.8874
# Experiment 5 - 101/200 val_roc: 0.8964 val_ap: 0.8991
# Experiment 5 - 151/200 val_roc: 0.9110 val_ap: 0.9174
# Experiment 5 result - ROC(AUC) score: 0.92619, AP score: 0.92907
# Experiment 6 - 1/200 val_roc: 0.8237 val_ap: 0.8150
# Experiment 6 - 51/200 val_roc: 0.8449 val_ap: 0.8540
# Experiment 6 - 101/200 val_roc: 0.8579 val_ap: 0.8699
# Experiment 6 - 151/200 val_roc: 0.9165 val_ap: 0.9241
# Experiment 6 result - ROC(AUC) score: 0.93625, AP score: 0.94186
# Experiment 7 - 1/200 val_roc: 0.8388 val_ap: 0.8331
# Experiment 7 - 51/200 val_roc: 0.8451 val_ap: 0.8505
# Experiment 7 - 101/200 val_roc: 0.8943 val_ap: 0.8974
# Experiment 7 - 151/200 val_roc: 0.9027 val_ap: 0.9083
# Experiment 7 result - ROC(AUC) score: 0.93858, AP score: 0.94302
# Experiment 8 - 1/200 val_roc: 0.8178 val_ap: 0.8065
# Experiment 8 - 51/200 val_roc: 0.8509 val_ap: 0.8548
# Experiment 8 - 101/200 val_roc: 0.9175 val_ap: 0.9205
# Experiment 8 - 151/200 val_roc: 0.9401 val_ap: 0.9441
# Experiment 8 result - ROC(AUC) score: 0.94683, AP score: 0.94923
# Experiment 9 - 1/200 val_roc: 0.8355 val_ap: 0.8401
# Experiment 9 - 51/200 val_roc: 0.8858 val_ap: 0.8817
# Experiment 9 - 101/200 val_roc: 0.8469 val_ap: 0.8583
# Experiment 9 - 151/200 val_roc: 0.9284 val_ap: 0.9260
# Experiment 9 result - ROC(AUC) score: 0.94287, AP score: 0.94417
# Experiment 10 - 1/200 val_roc: 0.8216 val_ap: 0.8321
# Experiment 10 - 51/200 val_roc: 0.8385 val_ap: 0.8505
# Experiment 10 - 101/200 val_roc: 0.8588 val_ap: 0.8710
# Experiment 10 - 151/200 val_roc: 0.9247 val_ap: 0.9260
# Experiment 10 result - ROC(AUC) score: 0.94494, AP score: 0.94835
# All experiments finished!
# Elapsed time: 3519.75s
# End time: 2021-09-09 01:28:49
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                             pubmed
# 2          datetime                                2021-09-09 01:28:49
# 3   experiment mode     simplified diffusion mode(n_diff=2, alpha=0.3)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.9322052898838771, 0.9377816833433252, 0.913...
# 8          roc_mean                                           0.934834
# 9           roc_std                                         0.00958988
# 10               ap  [0.9343521662163764, 0.9414797578598286, 0.920...
# 11          ap_mean                                           0.938754
# 12           ap_std                                         0.00847807
# 13  elapsed time(s)                                            3519.75
# Last data saved at: 2021-09-09 01:28:49
# Total data num: 197
# Dataset: pubmed
# Simdiff_params: n_diff =  2, alpha = 0.5
# Start time: 2021-09-09 01:28:49
# Experiment 1 - 1/200 val_roc: 0.8560 val_ap: 0.8472
# Experiment 1 - 51/200 val_roc: 0.9242 val_ap: 0.9148
# Experiment 1 - 101/200 val_roc: 0.8680 val_ap: 0.8784
# Experiment 1 - 151/200 val_roc: 0.9142 val_ap: 0.9207
# Experiment 1 result - ROC(AUC) score: 0.91607, AP score: 0.92146
# Experiment 2 - 1/200 val_roc: 0.8478 val_ap: 0.8387
# Experiment 2 - 51/200 val_roc: 0.9270 val_ap: 0.9196
# Experiment 2 - 101/200 val_roc: 0.8833 val_ap: 0.8914
# Experiment 2 - 151/200 val_roc: 0.9313 val_ap: 0.9345
# Experiment 2 result - ROC(AUC) score: 0.94726, AP score: 0.9485
# Experiment 3 - 1/200 val_roc: 0.8831 val_ap: 0.8698
# Experiment 3 - 51/200 val_roc: 0.8483 val_ap: 0.8563
# Experiment 3 - 101/200 val_roc: 0.8583 val_ap: 0.8677
# Experiment 3 - 151/200 val_roc: 0.9113 val_ap: 0.9151
# Experiment 3 result - ROC(AUC) score: 0.94312, AP score: 0.94766
# Experiment 4 - 1/200 val_roc: 0.8845 val_ap: 0.8823
# Experiment 4 - 51/200 val_roc: 0.9155 val_ap: 0.9023
# Experiment 4 - 101/200 val_roc: 0.8425 val_ap: 0.8549
# Experiment 4 - 151/200 val_roc: 0.9042 val_ap: 0.9066
# Experiment 4 result - ROC(AUC) score: 0.94271, AP score: 0.94706
# Experiment 5 - 1/200 val_roc: 0.8661 val_ap: 0.8546
# Experiment 5 - 51/200 val_roc: 0.8644 val_ap: 0.8625
# Experiment 5 - 101/200 val_roc: 0.8971 val_ap: 0.9057
# Experiment 5 - 151/200 val_roc: 0.9302 val_ap: 0.9352
# Experiment 5 result - ROC(AUC) score: 0.93923, AP score: 0.94123
# Experiment 6 - 1/200 val_roc: 0.8788 val_ap: 0.8683
# Experiment 6 - 51/200 val_roc: 0.8812 val_ap: 0.8795
# Experiment 6 - 101/200 val_roc: 0.9041 val_ap: 0.9083
# Experiment 6 - 151/200 val_roc: 0.9208 val_ap: 0.9238
# Experiment 6 result - ROC(AUC) score: 0.93538, AP score: 0.93708
# Experiment 7 - 1/200 val_roc: 0.8398 val_ap: 0.8399
# Experiment 7 - 51/200 val_roc: 0.8832 val_ap: 0.8843
# Experiment 7 - 101/200 val_roc: 0.9095 val_ap: 0.9166
# Experiment 7 - 151/200 val_roc: 0.9265 val_ap: 0.9311
# Experiment 7 result - ROC(AUC) score: 0.94399, AP score: 0.94594
# Experiment 8 - 1/200 val_roc: 0.8858 val_ap: 0.8776
# Experiment 8 - 51/200 val_roc: 0.9326 val_ap: 0.9237
# Experiment 8 - 101/200 val_roc: 0.8995 val_ap: 0.9092
# Experiment 8 - 151/200 val_roc: 0.9456 val_ap: 0.9500
# Experiment 8 result - ROC(AUC) score: 0.95084, AP score: 0.95152
# Experiment 9 - 1/200 val_roc: 0.8514 val_ap: 0.8479
# Experiment 9 - 51/200 val_roc: 0.8528 val_ap: 0.8483
# Experiment 9 - 101/200 val_roc: 0.8579 val_ap: 0.8704
# Experiment 9 - 151/200 val_roc: 0.9117 val_ap: 0.9202
# Experiment 9 result - ROC(AUC) score: 0.93102, AP score: 0.93514
# Experiment 10 - 1/200 val_roc: 0.8617 val_ap: 0.8462
# Experiment 10 - 51/200 val_roc: 0.8718 val_ap: 0.8774
# Experiment 10 - 101/200 val_roc: 0.8684 val_ap: 0.8804
# Experiment 10 - 151/200 val_roc: 0.9196 val_ap: 0.9271
# Experiment 10 result - ROC(AUC) score: 0.94232, AP score: 0.94609
# All experiments finished!
# Elapsed time: 3530.15s
# End time: 2021-09-09 02:27:39
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                             pubmed
# 2          datetime                                2021-09-09 02:27:39
# 3   experiment mode     simplified diffusion mode(n_diff=2, alpha=0.5)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.916072109306781, 0.9472556212449008, 0.9431...
# 8          roc_mean                                           0.939195
# 9           roc_std                                         0.00936531
# 10               ap  [0.9214566322814693, 0.9484977771403121, 0.947...
# 11          ap_mean                                           0.942167
# 12           ap_std                                          0.0084632
# 13  elapsed time(s)                                            3530.15
# Last data saved at: 2021-09-09 02:27:39
# Total data num: 198
# Dataset: pubmed
# Simdiff_params: n_diff =  2, alpha = 0.7
# Start time: 2021-09-09 02:27:39
# Experiment 1 - 1/200 val_roc: 0.8859 val_ap: 0.8771
# Experiment 1 - 51/200 val_roc: 0.9220 val_ap: 0.9163
# Experiment 1 - 101/200 val_roc: 0.8704 val_ap: 0.8863
# Experiment 1 - 151/200 val_roc: 0.9149 val_ap: 0.9232
# Experiment 1 result - ROC(AUC) score: 0.9155, AP score: 0.92081
# Experiment 2 - 1/200 val_roc: 0.8839 val_ap: 0.8779
# Experiment 2 - 51/200 val_roc: 0.9143 val_ap: 0.9116
# Experiment 2 - 101/200 val_roc: 0.9087 val_ap: 0.9164
# Experiment 2 - 151/200 val_roc: 0.9185 val_ap: 0.9269
# Experiment 2 result - ROC(AUC) score: 0.94825, AP score: 0.95213
# Experiment 3 - 1/200 val_roc: 0.8627 val_ap: 0.8558
# Experiment 3 - 51/200 val_roc: 0.9193 val_ap: 0.9108
# Experiment 3 - 101/200 val_roc: 0.9149 val_ap: 0.9214
# Experiment 3 - 151/200 val_roc: 0.9285 val_ap: 0.9342
# Experiment 3 result - ROC(AUC) score: 0.94483, AP score: 0.9486
# Experiment 4 - 1/200 val_roc: 0.8803 val_ap: 0.8828
# Experiment 4 - 51/200 val_roc: 0.9047 val_ap: 0.9013
# Experiment 4 - 101/200 val_roc: 0.8979 val_ap: 0.9030
# Experiment 4 - 151/200 val_roc: 0.9309 val_ap: 0.9339
# Experiment 4 result - ROC(AUC) score: 0.95035, AP score: 0.95366
# Experiment 5 - 1/200 val_roc: 0.8470 val_ap: 0.8385
# Experiment 5 - 51/200 val_roc: 0.8597 val_ap: 0.8729
# Experiment 5 - 101/200 val_roc: 0.8656 val_ap: 0.8810
# Experiment 5 - 151/200 val_roc: 0.9148 val_ap: 0.9245
# Experiment 5 result - ROC(AUC) score: 0.92171, AP score: 0.92828
# Experiment 6 - 1/200 val_roc: 0.8691 val_ap: 0.8655
# Experiment 6 - 51/200 val_roc: 0.8661 val_ap: 0.8742
# Experiment 6 - 101/200 val_roc: 0.8993 val_ap: 0.9059
# Experiment 6 - 151/200 val_roc: 0.9171 val_ap: 0.9241
# Experiment 6 result - ROC(AUC) score: 0.94601, AP score: 0.94827
# Experiment 7 - 1/200 val_roc: 0.8833 val_ap: 0.8788
# Experiment 7 - 51/200 val_roc: 0.8786 val_ap: 0.8732
# Experiment 7 - 101/200 val_roc: 0.8493 val_ap: 0.8631
# Experiment 7 - 151/200 val_roc: 0.9079 val_ap: 0.9159
# Experiment 7 result - ROC(AUC) score: 0.93057, AP score: 0.93425
# Experiment 8 - 1/200 val_roc: 0.8919 val_ap: 0.8812
# Experiment 8 - 51/200 val_roc: 0.8598 val_ap: 0.8605
# Experiment 8 - 101/200 val_roc: 0.8703 val_ap: 0.8828
# Experiment 8 - 151/200 val_roc: 0.9193 val_ap: 0.9272
# Experiment 8 result - ROC(AUC) score: 0.94045, AP score: 0.94524
# Experiment 9 - 1/200 val_roc: 0.8505 val_ap: 0.8507
# Experiment 9 - 51/200 val_roc: 0.9243 val_ap: 0.9217
# Experiment 9 - 101/200 val_roc: 0.9081 val_ap: 0.9202
# Experiment 9 - 151/200 val_roc: 0.9334 val_ap: 0.9423
# Experiment 9 result - ROC(AUC) score: 0.94463, AP score: 0.94601
# Experiment 10 - 1/200 val_roc: 0.8523 val_ap: 0.8565
# Experiment 10 - 51/200 val_roc: 0.8769 val_ap: 0.8726
# Experiment 10 - 101/200 val_roc: 0.9066 val_ap: 0.9134
# Experiment 10 - 151/200 val_roc: 0.9175 val_ap: 0.9254
# Experiment 10 result - ROC(AUC) score: 0.92709, AP score: 0.92981
# All experiments finished!
# Elapsed time: 3578.61s
# End time: 2021-09-09 03:27:18
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                             pubmed
# 2          datetime                                2021-09-09 03:27:18
# 3   experiment mode     simplified diffusion mode(n_diff=2, alpha=0.7)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.9155045680251274, 0.9482488184877946, 0.944...
# 8          roc_mean                                            0.93694
# 9           roc_std                                          0.0116311
# 10               ap  [0.9208104005552632, 0.9521344372274243, 0.948...
# 11          ap_mean                                           0.940705
# 12           ap_std                                          0.0108506
# 13  elapsed time(s)                                            3578.61
# Last data saved at: 2021-09-09 03:27:18
# Total data num: 199
# Dataset: pubmed
# Simdiff_params: n_diff =  2, alpha = 0.9
# Start time: 2021-09-09 03:27:18
# Experiment 1 - 1/200 val_roc: 0.8597 val_ap: 0.8470
# Experiment 1 - 51/200 val_roc: 0.8615 val_ap: 0.8612
# Experiment 1 - 101/200 val_roc: 0.8580 val_ap: 0.8697
# Experiment 1 - 151/200 val_roc: 0.9010 val_ap: 0.9074
# Experiment 1 result - ROC(AUC) score: 0.93427, AP score: 0.93758
# Experiment 2 - 1/200 val_roc: 0.8666 val_ap: 0.8632
# Experiment 2 - 51/200 val_roc: 0.9045 val_ap: 0.8964
# Experiment 2 - 101/200 val_roc: 0.9059 val_ap: 0.9090
# Experiment 2 - 151/200 val_roc: 0.9428 val_ap: 0.9427
# Experiment 2 result - ROC(AUC) score: 0.95042, AP score: 0.95243
# Experiment 3 - 1/200 val_roc: 0.8528 val_ap: 0.8448
# Experiment 3 - 51/200 val_roc: 0.8721 val_ap: 0.8704
# Experiment 3 - 101/200 val_roc: 0.9016 val_ap: 0.9100
# Experiment 3 - 151/200 val_roc: 0.9111 val_ap: 0.9199
# Experiment 3 result - ROC(AUC) score: 0.91053, AP score: 0.91716
# Experiment 4 - 1/200 val_roc: 0.8774 val_ap: 0.8777
# Experiment 4 - 51/200 val_roc: 0.8857 val_ap: 0.8844
# Experiment 4 - 101/200 val_roc: 0.9011 val_ap: 0.9098
# Experiment 4 - 151/200 val_roc: 0.9174 val_ap: 0.9250
# Experiment 4 result - ROC(AUC) score: 0.93376, AP score: 0.938
# Experiment 5 - 1/200 val_roc: 0.8650 val_ap: 0.8573
# Experiment 5 - 51/200 val_roc: 0.8994 val_ap: 0.8947
# Experiment 5 - 101/200 val_roc: 0.8432 val_ap: 0.8604
# Experiment 5 - 151/200 val_roc: 0.9038 val_ap: 0.9136
# Experiment 5 result - ROC(AUC) score: 0.92524, AP score: 0.92724
# Experiment 6 - 1/200 val_roc: 0.8693 val_ap: 0.8639
# Experiment 6 - 51/200 val_roc: 0.8708 val_ap: 0.8708
# Experiment 6 - 101/200 val_roc: 0.8584 val_ap: 0.8730
# Experiment 6 - 151/200 val_roc: 0.9062 val_ap: 0.9159
# Experiment 6 result - ROC(AUC) score: 0.93613, AP score: 0.93851
# Experiment 7 - 1/200 val_roc: 0.8641 val_ap: 0.8493
# Experiment 7 - 51/200 val_roc: 0.9078 val_ap: 0.9025
# Experiment 7 - 101/200 val_roc: 0.8576 val_ap: 0.8698
# Experiment 7 - 151/200 val_roc: 0.9241 val_ap: 0.9257
# Experiment 7 result - ROC(AUC) score: 0.93447, AP score: 0.93551
# Experiment 8 - 1/200 val_roc: 0.8741 val_ap: 0.8727
# Experiment 8 - 51/200 val_roc: 0.8665 val_ap: 0.8749
# Experiment 8 - 101/200 val_roc: 0.9062 val_ap: 0.9126
# Experiment 8 - 151/200 val_roc: 0.9359 val_ap: 0.9403
# Experiment 8 result - ROC(AUC) score: 0.94105, AP score: 0.94458
# Experiment 9 - 1/200 val_roc: 0.8367 val_ap: 0.8341
# Experiment 9 - 51/200 val_roc: 0.8728 val_ap: 0.8703
# Experiment 9 - 101/200 val_roc: 0.8492 val_ap: 0.8642
# Experiment 9 - 151/200 val_roc: 0.9041 val_ap: 0.9090
# Experiment 9 result - ROC(AUC) score: 0.91686, AP score: 0.92072
# Experiment 10 - 1/200 val_roc: 0.8724 val_ap: 0.8651
# Experiment 10 - 51/200 val_roc: 0.8796 val_ap: 0.8767
# Experiment 10 - 101/200 val_roc: 0.8616 val_ap: 0.8745
# Experiment 10 - 151/200 val_roc: 0.9215 val_ap: 0.9244
# Experiment 10 result - ROC(AUC) score: 0.93606, AP score: 0.94089
# All experiments finished!
# Elapsed time: 3531.51s
# End time: 2021-09-09 04:26:09
#                 key                                              value
# 0             model                                               vgae
# 1           dataset                                             pubmed
# 2          datetime                                2021-09-09 04:26:09
# 3   experiment mode     simplified diffusion mode(n_diff=2, alpha=0.9)
# 4     setting_order  [epochs, hidden1, hidden2, lr, dropout, test_v...
# 5     setting_value  (200, 32, 16, 0.01, 0.0, [0.1, 0.05], False, T...
# 6         iteration                                                 10
# 7               roc  [0.9342721216880189, 0.9504206260833582, 0.910...
# 8          roc_mean                                           0.931879
# 9           roc_std                                          0.0109768
# 10               ap  [0.9375775412560284, 0.9524330269430032, 0.917...
# 11          ap_mean                                           0.935264
# 12           ap_std                                          0.0101992
# 13  elapsed time(s)                                            3531.51
# Last data saved at: 2021-09-09 04:26:09
# Total data num: 200

# %% [markdown]
# ### VGAE(single operation)

# %%
# results = vgae_iter(adj, features, hparams, feature_use=feature_use, n_iter=n_iter)

# %% [markdown]
# ### Save log

# %%
# date = (datetime.now() + timedelta(hours=9)).strftime("%Y-%m-%d %H:%M:%S")
# hparams_add = hparams[:-2] + (feat_norm,) + (feature_use,)
# if n_diff == 1 and alpha == 0.5:
#     experiment_mode = 'normal mode(n_diff={}, alpha={})'.format(n_diff, alpha)
# else:
#     experiment_mode = 'simplified diffusion mode(n_diff={}, alpha={})'.format(n_diff, alpha)

# %%
# log_dict= OrderedDict()

# %%
# log_dict['model'] = model_name
# log_dict['dataset'] = dataset
# log_dict['datetime'] = date
# log_dict['experiment mode'] =  experiment_mode
# log_dict['setting_order'] = ['epochs', 'hidden1', 'hidden2', 'lr', 'dropout', 'test_val_ratio', 'feat_norm', 'feat_use']
# log_dict['setting_value'] = hparams_add
# log_dict['iteration'] = n_iter
# log_dict['roc'] = results[0]
# log_dict['roc_mean'] = np.mean(results[0])
# log_dict['roc_std'] = np.std(results[0])
# log_dict['ap'] = results[1]
# log_dict['ap_mean'] = np.mean(results[1])
# log_dict['ap_std'] = np.std(results[1])
# log_dict['elapsed time(s)'] = np.round(results[2], 4)
# pd.DataFrame(log_dict.items(), columns=['key', 'value'])

# %%
# data = json.load(open('results_link_prediction.json'))
# data.append(log_dict)
# with open('results_link_prediction.json', 'w') as f:
#     json.dump(data, f)
# print("Last data saved at: {}".format((datetime.now() + timedelta(hours=9)).strftime("%Y-%m-%d %H:%M:%S")))
# print("Total data num: {}".format(len(data)))
# Out:
# Last data saved at: 2021-09-03 11:07:55
# Total data num: 12

# %%
# if wanna clear results(be careful!)
# empty = []
# with open('results_link_prediction.json', 'w') as f:
#     json.dump(empty, f)

# %% [markdown]
# ### Define VGAE

# %%
def vgae_iter(adj, features, hparams, feature_use=False, n_iter=1):
    
    epochs, hidden1, hidden2, lr, dropout, test_val_ratio, n_diff, alpha = hparams
    test = 1/test_val_ratio[0]
    val = 1/test_val_ratio[1]
    roc_results = []
    ap_results = []
    start = time.time()
    print("Dataset: {}".format(dataset))
    print("Simdiff_params: n_diff =  {}, alpha = {}".format(n_diff, alpha))
    print("Start time: {}".format((datetime.now() + timedelta(hours=9)).strftime("%Y-%m-%d %H:%M:%S")))
    
    for i in range(n_iter):
        adj_orig = remove_diag(adj)
        while True:
            try:
                adj_train, train_edges, val_edges, val_edges_false, test_edges, test_edges_false = mask_test_edges(adj, test, val)
            except AssertionError:
                continue
            break
        adj_ = adj_train
        adj_norm = preprocess_graph_diff(adj_, n_diff, alpha)
            
        pos_weight = torch.Tensor([float(adj.shape[0] * adj.shape[0] - adj.sum()) / adj.sum()])
        norm = adj.shape[0] * adj.shape[0] / float((adj.shape[0] * adj.shape[0] - adj.sum()) * 2)
        
        if feature_use == False:
            features = sp.identity(adj.shape[0])
            features = torch.FloatTensor(np.array(features.todense()))
        n_nodes, feat_dim = features.shape
            
        adj_label = adj_train + sp.eye(adj_train.shape[0])
        adj_label = torch.FloatTensor(adj_label.toarray())
 
        adj_norm, features, adj_label, pos_weight = adj_norm.to(device), features.to(device), adj_label.to(device), pos_weight.to(device)
        
        model = GCN_VAE(feat_dim, hidden1, hidden2, dropout)
        model= model.to(device)
        optimizer = optim.Adam(model.parameters(), lr=lr)
        hidden_emb = None
        
        for epoch in range(epochs):
            model.train()
            optimizer.zero_grad()
            recovered, mu, logvar = model(features, adj_norm)
            while True:
                try:
                    loss = loss_function(preds=recovered, labels=adj_label, mu=mu, logvar=logvar, n_nodes=n_nodes, norm=norm, pos_weight=pos_weight)
                except RuntimeError:
                    continue
                break
            loss.backward()
            cur_loss = loss.item()
            optimizer.step()
 
            hidden_emb = mu.data.cpu().numpy()
            roc_curr, ap_curr = get_roc_score_vgae(hidden_emb, adj_orig, val_edges, val_edges_false)
            if epoch % 50 == 0:
                print('Experiment {} - {}/{} val_roc: {:.4f} val_ap: {:.4f}'.format(i+1, epoch+1, epochs, roc_curr, ap_curr), end='\n', flush=True)
 
        roc_score, ap_score = get_roc_score_vgae(hidden_emb, adj_orig, test_edges, test_edges_false)
        roc_results.append(roc_score)
        ap_results.append(ap_score)
        print('Experiment {} result - ROC(AUC) score: {}, AP score: {}'.format(i+1, np.round(roc_score, 5), np.round(ap_score, 5)), end='\n')
    elapsed_time = time.time()-start
    print('All experiments finished!', '\nElapsed time: {:.2f}s'.format(elapsed_time), end='\n')
    print("End time: {}".format((datetime.now() + timedelta(hours=9)).strftime("%Y-%m-%d %H:%M:%S")))
    return roc_results, ap_results, elapsed_time
